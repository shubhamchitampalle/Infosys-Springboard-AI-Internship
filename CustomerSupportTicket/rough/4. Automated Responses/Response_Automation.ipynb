# %%
#sheets_link = "https://docs.google.com/spreadsheets/d/1tyxACc95GD88T2Me_xhktYbc14P6-BBZkOWlT7MUaeU"
#sheet_link2 ="https://docs.google.com/spreadsheets/d/1Ht23dgNixm40ZF8etrGH1584oaObYwUekske9G06IKk"

# %% [markdown]
# # Response Automation

# %%
# !pip install "gspread==6.1.3"
# Out:
# Collecting gspread==6.1.3
#   Downloading gspread-6.1.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: google-auth>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from gspread==6.1.3) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from gspread==6.1.3) (1.2.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.12.0->gspread==6.1.3) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.12.0->gspread==6.1.3) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.12.0->gspread==6.1.3) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib>=0.4.1->gspread==6.1.3) (1.3.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread==6.1.3) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread==6.1.3) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread==6.1.3) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread==6.1.3) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread==6.1.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread==6.1.3) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread==6.1.3) (2024.12.14)
# Downloading gspread-6.1.3-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: gspread
#   Attempting uninstall: gspread
#     Found existing installation: gspread 6.1.4
#     Uninstalling gspread-6.1.4:
#       Successfully uninstalled gspread-6.1.4
# Successfully installed gspread-6.1.3

# %%
import gspread
from google.oauth2.service_account import Credentials

scopes = [
    'https://www.googleapis.com/auth/spreadsheets',
    'https://www.googleapis.com/auth/drive'
]

credentials = Credentials.from_service_account_file(
    '/content/my-project-response-29749ee50e47.json',
    scopes=scopes
)

gc = gspread.authorize(credentials)
sh = gc.open_by_key("1tyxACc95GD88T2Me_xhktYbc14P6-BBZkOWlT7MUaeU")

# %%
# prompt: read sheet into pandas frame
import pandas as pd
# Assuming 'sh' is your opened Google Sheet from the previous code
worksheet = sh.sheet1  # Or specify the correct sheet name or index

# Get all values from the worksheet
data = worksheet.get_all_values()

# Convert to DataFrame
df_sheets = pd.DataFrame(data[1:], columns=data[0])  # First row is header
df_sheets.head()
# Out:
#               id                                            subject  \
# 0  1001352387736  Urgent: Critical impact on enterprise network ...
# 1  1004699418379     Intermittent Cursor Freezing Issue on Dell XPS
# 2  1006966905046  Dringend: Unterstützung für die Datenwiederher...
# 3  1009231330404           Anfrage zu den MacBook Air M1 Funktionen
# 4  1024440081041  Solicitação de Assistência com Erro de Instala...
#
#                                                 body  \
# 0  Dear Customer Support Team, We are experiencin...
# 1  Dear Customer Support,<br><br>I hope this mess...
# 2  Hallo, wir haben severe Datenverluste in MySQL...
# 3  Sehr geehrtes Kundenserviceteam,\n\n\nich hoff...
# 4  Caro Suporte ao Cliente,\n\n\nEstou enfrentand...
#
#                                               answer      type  \
# 0  Subject: Re: Urgent: Critical impact on enterp...  Incident
# 1  Dear <name>,\n\n\nThank you for reaching out r...  Incident
# 2  Hallo, vielen Dank, dass Sie uns kontaktiert h...  Incident
# 3  Sehr geehrter <name>,\n\n\nvielen Dank für Ihr...   Request
# 4  Caro <name>,\n\n\nObrigado por entrar em conta...   Problem
#
#                  queue priority language      business_type  \
# 0    Technical Support     high       en        IT Services
# 1      Product Support      low       en  Tech Online Store
# 2    Technical Support     high       de        IT Services
# 3  Sales and Pre-Sales      low       de  Tech Online Store
# 4    Technical Support   medium       pt        IT Services
#
#                tag_1            tag_2              tag_3               tag_4  \
# 0     Service Outage    Network Issue       Urgent Issue   Technical Support
# 1  Technical Support  Product Support   Hardware Failure  Problem Resolution
# 2        Data Breach   Backup Restore  Technical Support        Urgent Issue
# 3   Customer Service  Product Support      Sales Inquiry  Technical Guidance
# 4  Technical Support     Software Bug       Urgent Issue  Problem Resolution
#
#                 tag_5               tag_6                  tag_7  \
# 0  Problem Resolution    Critical Failure           System Crash
# 1        Urgent Issue    Service Recovery  Documentation Request
# 2        Software Bug  Problem Resolution
# 3      Warranty Claim     General Inquiry
# 4     Product Support
#
#                 tag_8 tag_9
# 0  Service Disruption
# 1
# 2
# 3
# 4

# %%
df_eng = df_sheets.loc[df_sheets["language"].eq("en"), :]
df_eng.head()
# Out:
#               id                                            subject  \
# 0  1001352387736  Urgent: Critical impact on enterprise network ...
# 1  1004699418379     Intermittent Cursor Freezing Issue on Dell XPS
# 5  1024619926727    Exchange Request for Malfunctioning Dell XPS 13
# 6  1026487543175       Request for Server Administration Assistance
# 7  1027850274374   Immediate Attention Required: AWS Outage Concern
#
#                                                 body  \
# 0  Dear Customer Support Team, We are experiencin...
# 1  Dear Customer Support,<br><br>I hope this mess...
# 5  Dear Tech Online Store Customer Support,\n\n\n...
# 6  Dear IT Services Customer Support, \n\n\nWe ar...
# 7  Greetings IT Services Customer Support,\n\n\nI...
#
#                                               answer      type  \
# 0  Subject: Re: Urgent: Critical impact on enterp...  Incident
# 1  Dear <name>,\n\n\nThank you for reaching out r...  Incident
# 5  Dear <name>,\n\n\nThank you for reaching out a...    Change
# 6  Subject: Re: Request for Server Administration...   Request
# 7  Hello <name>,\n\n\nWe appreciate you informing...  Incident
#
#                    queue priority language      business_type  \
# 0      Technical Support     high       en        IT Services
# 1        Product Support      low       en  Tech Online Store
# 5  Returns and Exchanges   medium       en  Tech Online Store
# 6        Product Support   medium       en        IT Services
# 7      Technical Support     high       en        IT Services
#
#                    tag_1                tag_2               tag_3  \
# 0         Service Outage        Network Issue        Urgent Issue
# 1      Technical Support      Product Support    Hardware Failure
# 5  Returns and Exchanges  Product Replacement    Customer Service
# 6      Technical Support           IT Support  Performance Tuning
# 7         Service Outage         Urgent Issue          IT Support
#
#                 tag_4               tag_5             tag_6  \
# 0   Technical Support  Problem Resolution  Critical Failure
# 1  Problem Resolution        Urgent Issue  Service Recovery
# 5   Technical Support         Order Issue
# 6  Problem Resolution  Technical Guidance  Service Recovery
# 7  System Maintenance     Incident Report  Customer Service
#
#                    tag_7               tag_8 tag_9
# 0           System Crash  Service Disruption
# 1  Documentation Request
# 5
# 6
# 7

# %%
tickets = df_eng.loc[:, ["body", "answer"]].apply(lambda x: f"Body: {x['body']} \n\n\n Answer: {x['answer']}", axis=1)
print(tickets[0])
# Out:
# Body: Dear Customer Support Team, We are experiencing a complete outage affecting our enterprise network involving Cisco Router ISR4331. This disruption is critically impacting our secure WAN connectivity across all domains, urgently requiring your immediate intervention. Due to this issue, our company has halted various essential operations, significantly affecting our services and commitments to clients. As our technical team has not been able to resolve the problem internally, we need your expert support to diagnose and rectify this issue swiftly. Please consider this a high priority and provide us with the necessary technical assistance to restore our network’s functionality. Thank you for your prompt attention. Best regards, <name>, IT Manager at <company>
#
#
#  Answer: Subject: Re: Urgent: Critical impact on enterprise network connectivity
#
#
# Dear <name>,
#
#
# Thank you for reaching out to us regarding the critical outage affecting your Cisco Router ISR4331.
#
#
# We understand the urgency and impact of this issue on your operations. Our technical support team is prioritizing your case and will promptly begin diagnosing the problem to facilitate a quick resolution.
#
#
# Please ensure all relevant technical logs are available for our team to access, which will assist in expediting the diagnostic process. We will maintain close communication and provide updates as our investigation proceeds.
#
#
# Your patience and cooperation are greatly appreciated, and we're committed to resolving this matter as swiftly as possible.
#
#
# Best regards,
#
#
# Customer Support Team

# %%
# prompt: from the tickets remove stop words, lemmatize it and use tdidf vectorizer, tokinize the text, remove stopwords, lematize the tokens

import nltk
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    tokens = nltk.word_tokenize(text.lower())
    tokens = [lemmatizer.lemmatize(token) for token in tokens if token.isalnum() and token not in stop_words]
    return ' '.join(tokens)

# Assuming 'tickets' is your Series from the previous code
# Example:
# tickets = df_eng.loc[:, ["body", "answer"]].apply(lambda x: f"Body: {x['body']} \n\n\n Answer: {x['answer']}", axis=1)

preprocessed_tickets = tickets.apply(preprocess_text)

vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(preprocessed_tickets)

# Now 'tfidf_matrix' contains the TF-IDF representation of the preprocessed ticket texts.

# feature_names = vectorizer.get_feature_names_out()
# tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=feature_names)
# print(tfidf_df.head())
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
# prompt: use pca to get top 3 pcas on tfidf_matrix
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
pca_result = pca.fit_transform(tfidf_matrix.toarray())
pca_df = pd.DataFrame(data=pca_result, columns=['PC1', 'PC2', 'PC3'])
print(pca_df.head())
# Out:
#         PC1       PC2       PC3
# 0  0.031656  0.396048 -0.034011
# 1  0.137482 -0.077097 -0.168872
# 2  0.165454 -0.278548 -0.174218
# 3 -0.188035  0.032300 -0.084387
# 4 -0.273859  0.099750  0.009601

# %%
# prompt: combine and tokenzie all tags columns (tag_1 to tag_9) and sort tokens and make a string of unique tokens

# Combine tag columns
tag_columns = [col for col in df_eng.columns if col.startswith('tag_')]
df_eng['combined_tags'] = df_eng[tag_columns].apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)

# Tokenize, sort, and create a string of unique tokens
def process_tags(text):
    tokens = nltk.word_tokenize(text.lower())
    tokens = [lemmatizer.lemmatize(token) for token in tokens if token.isalnum() and token not in stop_words]
    unique_tokens = sorted(list(set(tokens)))
    return ' '.join(unique_tokens)

df_eng['unique_tags'] = df_eng['combined_tags'].apply(process_tags)
df_eng['unique_tags'].value_counts()
# Out:
# <ipython-input-8-8eb3fe769c00>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eng['combined_tags'] = df_eng[tag_columns].apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
# <ipython-input-8-8eb3fe769c00>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eng['unique_tags'] = df_eng['combined_tags'].apply(process_tags)
# unique_tags
# disruption issue network problem resolution service support technical urgent                                        5
# account assistance billing customer issue problem resolution service urgent                                         3
# bug disruption issue maintenance problem resolution service software support system technical urgent                3
# disruption incident issue maintenance problem recovery report resolution service support system technical urgent    3
# bug issue problem product resolution software support technical urgent                                              3
#                                                                                                                    ..
# feature guidance problem product request resolution support technical                                               1
# account assistance billing issue payment processing support technical                                               1
# customer feature general inquiry product request sale service support technical                                     1
# bug feature issue maintenance problem product request resolution software support system technical urgent           1
# guidance issue network performance problem recovery resolution service support technical tuning urgent              1
# Name: count, Length: 291, dtype: int64

# %%
# prompt: pca_result variance explained

# Assuming 'pca' is the PCA object fitted to your data (tfidf_matrix)
explained_variance_ratio = pca.explained_variance_ratio_

# Print the explained variance ratio for each principal component
print("Explained Variance Ratio per Principal Component:")
for i, variance in enumerate(explained_variance_ratio):
    print(f"PC{i+1}: {variance:.4f}")

# Calculate and print the total variance explained by the selected components
total_variance_explained = sum(explained_variance_ratio)
print(f"\nTotal Variance Explained by all components: {total_variance_explained:.4f}")
# Out:
# Explained Variance Ratio per Principal Component:
# PC1: 0.0402
# PC2: 0.0315
# PC3: 0.0258
#
# Total Variance Explained by all components: 0.0975

# %%
# prompt: screen plot it
import matplotlib.pyplot as plt

# Assuming 'pca' is the PCA object fitted to your data (tfidf_matrix)
explained_variance_ratio = pca.explained_variance_ratio_

# Create the scree plot
plt.figure(figsize=(8, 6))
plt.plot(range(1, len(explained_variance_ratio) + 1), explained_variance_ratio, marker='o')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.title('Scree Plot')
plt.grid(True)
plt.show()

# %%
import plotly.express as px

# Assuming pca_df and df_en are already defined from the previous code

fig = px.scatter_3d(pca_df, x='PC1', y='PC2', z='PC3', color=df_eng['unique_tags'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f0ef9a0b-8731-4579-9f71-5039a396e546" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f0ef9a0b-8731-4579-9f71-5039a396e546")) {                    Plotly.newPlot(                        "f0ef9a0b-8731-4579-9f71-5039a396e546",                        [{"hovertemplate":"color=crash critical disruption failure issue network outage problem resolution service support system technical urgent\u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003ePC3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"crash critical disruption failure issue network outage problem resolution service support system technical urgent","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"crash critical disruption failure issue network outage problem resolution service support system technical urgent","scene":"scene","showlegend":true,"x":[0.031656311257238806],"y":[0.39604771137499867],"z":[-0.03401091673211035],"type":"scatter3d"},{"hovertemplate":"color=documentation failure hardware issue problem product recovery request resolution service support technical urgent\u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003ePC3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"documentation failure hardware issue problem product recovery request resolution service support technical urgent","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"documentation failure hardware issue problem product recovery request resolution service support technical urgent","scene":"scene","showlegend":true,"x":[0.13748171336030357],"y":[-0.07709748198608282],"z":[-0.1688715256704748],"type":"scatter3d"},{"hovertemplate":"color=customer exchange issue order product replacement return service support technical\u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003ePC3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"customer exchange issue order product replacement return service support technical","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"customer exchange issue order product replacement return service support technical","scene":"scene","showlegend":true,"x":[0.16545381110134824],"y":[-0.2785476053957047],"z":[-0.1742180179155732],"type":"scatter3d"},{"hovertemplate":"color=guidance performance problem recovery resolution service support technical tuning\u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003ePC3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"guidance performance problem recovery resolution service support technical tuning","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"guidance performance problem recovery resolution service support technical tuning","scene":"scene","showlegend":true,"x":[-0.18803507069215433,-0.14977614700231853],"y":[0.032299758946460436,0.003984970499712765],"z":[-0.08438746958363401,0.010855151186128837],"type":"scatter3d"},{"hovertemplate":"color=customer incident issue maintenance outage report service support system urgent\u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003ePC3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"customer incident issue maintenance outage report service support system urgent","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"customer incident issue maintenance outage report service support system urgent","scene":"scene","showlegend":true,"x":[-0.2738591305232797],"y":[0.09974953439955395],"z":[0.009601159266014962],"type":"scatter3d"},{"hovertemplate":"color=bug customer guidance issue problem resolution service software support technical urgent\u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003ePC3=%{z}\u003cext ...

# %%
import plotly.express as px

# Assuming pca_df and df_en are already defined from the previous code

fig = px.scatter_3d(pca_df, x='PC1', y='PC2', z='PC3', color=df_eng.index)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="89f7b959-69fa-4d77-ab7d-3ac11c2ce417" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("89f7b959-69fa-4d77-ab7d-3ac11c2ce417")) {                    Plotly.newPlot(                        "89f7b959-69fa-4d77-ab7d-3ac11c2ce417",                        [{"hovertemplate":"PC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003ePC3=%{z}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[0,1,5,6,7,8,11,13,18,20,21,23,24,26,32,37,39,40,43,48,49,52,53,56,59,63,65,66,70,72,74,78,81,82,83,84,87,92,95,104,106,107,112,116,117,118,120,121,123,127,129,130,131,136,137,140,143,146,148,153,156,160,161,163,167,168,169,170,171,173,174,176,183,184,190,191,194,197,201,202,203,205,207,213,214,221,222,224,225,226,228,233,234,236,240,241,244,249,251,253,256,265,268,269,271,272,277,278,279,281,283,284,291,293,296,302,305,309,310,315,318,322,327,332,334,338,342,345,347,349,350,354,358,361,367,372,373,375,378,379,383,384,386,390,400,401,408,412,413,414,416,417,418,422,424,426,430,431,433,437,438,444,448,449,451,453,454,461,468,469,472,480,482,484,487,488,493,495,497,500,501,506,512,514,518,519,521,528,530,536,543,544,570,571,572,579,581,584,587,591,596,598,599,600,603,611,612,613,619,622,623,626,629,632,633,636,640,644,645,653,662,672,680,686,687,689,690,705,706,707,708,714,719,720,725,729,732,737,748,756,759,775,776,779,780,789,790,791,792,809,813,814,817,820,825,832,845,847,853,867,872,874,877,879,892,894,895,906,917,919,921,928,931,935,946,961,969,980,993,998,1009,1026,1027,1036,1037,1041,1058,1060,1061,1062,1064,1090,1092,1100,1101,1108,1121,1129,1134,1136,1143,1147,1158,1162,1173,1175,1222,1232,1236,1277,1282,1289,1299,1301,1314,1324,1330,1340,1343,1346,1354,1364,1371,1378,1385,1395,1408,1423,1430,1435,1440,1447,1498,1512,1517,1528,1536,1537,1561],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[0.031656311257238806,0.13748171336030357,0.16545381110134824,-0.18803507069215433,-0.2738591305232797,-0.037007924554018516,0.044811984441884514,-0.21198467339710364,-0.28848749243824784,0.024574879791220177,-0.21057029458754647,0.33071371707282776,-0.22884890025857527,-0.13559749650945893,-0.012795611319179357,0.4216993977880658,0.21942734313943685,-0.2372867533446859,-0.22013879874891668,0.09583636626570877,0.11663175629830633,0.12152638162492435,0.45480888682198056,-0.15093598191354,0.08546313634625788,0.21603629057480372,0.11215000579748516,0.34185945562628695,-0.05697619264372207,-0.19291973997706752,0.13675127528848832,0.13238622056510282,-0.2447645048376588,0.01372392796845204,-0.26481518654939945,-0.19393426674878056,-0.14210135490799916,-0.04687764558279838,0.40231124604615554,-0.12692142450178456,0.10225435700783496,-0.246287492157527,-0.09110835210586532,-0.09344792352077959,0.2514851159771376,0.13463362090468003,0.2092620682977649,0.08201606484657047,0.12306501423805642,0.1436204723875857,0.13652301259162156,0.10597609010927819,0.03282196154971983,0.18880696071947467,0.09796421646221681,-0.04216640639824689,0.07107429398361437,0.11719848172135443,0.20436925591789323,0.03478230542333133,-0.09556430507315483,-0.13302346124856035,-0.0725354039536604,0.1626317199019089,0.2070576115969045,0.23441608380361684,-0.14349299729486115,-0.18669468070841466,0.046482412745432966,-0.14977614700231853,-0.06509763047638087,0.27832627846374475,-0.1874745379294042,0.008601214355120181,0.43653271333219906,0.16314786253635433,0.45934993555028575,-0.23551100816179726,-0.2005577629776062,0.16470195683214608,-0.26430851473004574,-0.10532108194965485,0.044331902059848584,-0.022907753435266645,0.042178178168172695,-0.09855296487915613,0.3700534237154692,0. ...

# %%
df_eng.loc[[980, 817, 293, 433, 43, 633], ["subject", "body", "answer"]].values
# Out:
# array([['Urgent Issue with AWS Deployment',
#         'Dear IT Services Support Team, I am writing to inform you of a critical issue we are experiencing with our AWS infrastructure deployment, which is significantly affecting our cloud service operational efficiency and cost optimization efforts. The problem seems related to the AWS Management Service, causing disruptions in our regular business operations. We urgently require your assistance to rectify this issue. Please escalate this as a high-priority incident and advise on the next possible steps. Attached are relevant logs and performance data for your reference. Looking forward to your swift response. Thank you, <name>.',
#         'Dear <name>,\n\n\nThank you for reaching out to us regarding the issue with your AWS deployment. We understand the urgency of the situation and have escalated this as a high-priority incident as per your request.\n\n\nOur team is currently reviewing the logs and performance data you provided to diagnose the problem with the AWS Management Service. We assure you that resolving this matter is our top priority. We will keep you posted on our findings and the next steps needed to restore your operational efficiency.\n\n\nWe appreciate your patience and cooperation in this matter. Please feel free to contact us if you have any further questions or receive additional information.\n\n\nBest regards,\nIT Services Support Team'],
#        ['Immediate Attention Required',
#         'Hello Customer Support Team, We are encountering significant issues related to high latency which is impacting our AWS Management Service. This situation necessitates immediate intervention to restore full functionality. Kindly give precedence to this matter and offer an estimated timeline for resolution. Your prompt assistance is greatly valued. Warm regards, <name>',
#         "Dear <name>,\n\n\nThank you for your message. We recognize the importance of the high latency issue that is affecting your AWS Management Service. Our technical team is currently looking into the situation to ensure a swift resolution. Although we endeavor to address issues as quickly as possible, we currently can't guarantee an exact timeline for complete restoration. Please know that this is our utmost priority, and we will provide updates on our progress. We appreciate your patience and understanding.\n\n\nSincerely, \nService Desk Team"],
#        ['Urgent Assistance Needed for AWS Access Issue',
#         "Dear IT Consulting Firm Support Team,\n\n\nI am writing to bring to your immediate attention an issue we are facing with accessing the AWS Console through your provided AWS Management Service. Our client, <name>, is currently receiving a domain DNS error which is preventing access to essential services within the AWS Console. The ability to access this platform is critically urgent as we have a scheduled deployment that is dependent on these resources.\n\n\nThe client attempted to access the console on their end and received an error message indicating there may be a DNS configuration issue. We understand the importance of domain and DNS accuracy in ensuring seamless service access. Hence, we're reaching out to your expert support team to assist in resolving this matter as quickly as possible.\n\n\nPlease advise on the steps needed to rectify this situation. If necessary, a technician may need to walk us through the adjustments required in the DNS settings. Our point of contact, <name>, can be reached at <tel_num> for any detailed discussions or immediate support.\n\n\nThank you for your prompt attention to this urgent matter.\n\n\nBest Regards,\n<name>\n<company_name>",
#         'Dear <name>,\n\n\nThank you for reaching out regarding the AWS Console access issue. We understand the urgency and are committed to resolving the DNS configuration problem swiftly.\n\n\nTo address this, please ensure that your DNS settings are correctly pointed to the appropriate AWS nameservers and that no recent changes have occurred. As a preliminary step, you might want to flush your DNS cache and verify the settings on your network devices.\n\n\nOur technical team is reviewing the situation, and I will have a technician contact your point of contact, <name>, at <tel_num> shortly to assist with any necessary adjustments.\n\n\nThank you for your patience and cooperation.\n\n\nBest regards,\n[Your Name]\nIT Consulting Firm Support Team'],
#        ['Critical: Significant AWS Service Disruption',
#         'Dear Customer Support Team of IT Services, I am reaching out to highlight an urgent issue regarding a significant AWS service disruption that is severely affecting our cloud systems. Our operational activities are heavily reliant on the AWS Management Service, and this unexpected interruption is hindering our capacity to efficiently serve our clients. We kindly seek immediate action and resolution to reduce downtime and avert further issues. The situation is pressing, and a prompt resolution would be immensely appreciated. Kindly inform us about the measures you are implementing to address this outage at your earliest convenience. We appreciate your assistance and look forward to your rapid response. Should you require any additional details or coordination, please contact me at <tel_num> or reply to this email. Thank you for prioritizing this urgent matter. Kind regards, <name> <Position> <Company Name> <tel_num>',
#         'Dear <name>,\n\n\nWe appreciate you reaching out about the AWS outage impacting your cloud systems. We recognize the urgency of this matter and its effects on your business operations. Our team is actively collaborating with AWS to evaluate and resolve the problem as swiftly as possible. We are dedicated to mitigating downtime and will keep you updated on any advancements or resolutions as soon as they arise.\n\n\nPlease rest assured that we are deploying all necessary resources to lessen the impact and restore full functionality. If you need further escalation or extra information, do not hesitate to get in touch with us using the provided contact details.\n\n\nWe thank you for your understanding and cooperation as we work diligently to address this pressing issue.\n\n\nBest regards,\n\n\nIT Services Customer Support Team'],
#        ['Urgent AWS Connectivity Issue',
#         "We are experiencing connectivity issues with the AWS Management Service, resulting in disruptions to our client's website. We require an urgent resolution. Please prioritize this major incident. Account Number: <acc_num>. Thank you, <name>.",
#         "Subject: Re: Urgent AWS Connectivity Issue\n\n\nDear <name>,\n\n\nThank you for reaching out. We understand the critical nature of the connectivity issue with the AWS Management Service that is impacting your client's website. Our team is treating this incident with utmost urgency and is diligently working to restore the service. We will update you on our progress regularly. If you have any further information to share, please feel free to reach out to us.\n\n\nBest regards,\nService Desk Team"],
#        ['Urgent: AWS Downtime Issue',
#         'Dear IT Services Customer Support,\n\n\nMy name is <name>, and I am reaching out to report an urgent issue with our AWS Management Service, account number <acc_num>. We have been experiencing significant downtime, which is critically affecting our operations. As we rely heavily on AWS services for our cloud infrastructure, this disruption has severely impacted our business continuity.\n\n\nOur team noticed the downtime affecting multiple components within our ecosystem since <start_time>. We initially believed this was a minor glitch; however, despite our attempts to rectify the issue, the downtime persists. Efforts such as restarting services and consulting initial support documentation have yielded no results. \n\n\nWe are seeking immediate assistance from your specialized cloud infrastructure team to investigate and resolve this issue. The matter is time-sensitive, and rapid intervention is imperative to restoring our operations. We would appreciate if your team could prioritize the investigation and keep us updated on progress and findings. Furthermore, could you please ensure that additional resources are allocated to expedite the resolution process?\n\n\nPlease feel free to reach me at <email> or by phone at <tel_num>. We are looking forward to your swift response to this urgent situation. Thank you for your immediate attention to this critical matter.\n\n\nBest regards,\n<name>',
#         'Dear <name>,\n\n\nThank you for reaching out to us regarding the AWS downtime issue. We understand the critical nature of this situation and are prioritizing it for immediate review and resolution by our specialized cloud infrastructure team. \n\n\nPlease be assured that we are allocating all necessary resources to expedite the process and will keep you updated with our progress and findings. Our team will reach out to you promptly to provide the needed assistance. \n\n\nFor further communication, feel free to contact me directly at <email> or <tel_num>. We appreciate your patience and cooperation as we work swiftly to restore your operations.\n\n\nBest regards,\nIT Services Customer Support']],
#       dtype=object)

# %%
df_eng.loc[[194, 626, 536, 906, 53, 931], ["subject", "answer"]].values
# Out:
# array([['Assistance Needed for Printer Setup',
#         'Dear <name>,\n\n\nThank you for reaching out to us regarding your Canon PIXMA MG3620 printer Wi-Fi setup. I\'m here to assist you. Please ensure that your wireless router is on, and place your printer within range without any obstructions. If possible, restart both your router and printer. Next, check that your printer is in "Wireless" mode and attempt the Wi-Fi setup process again following these steps:\n\n\n1. Press the Wi-Fi button on the printer until the ON light flashes. \n2. Go to your device\'s Wi-Fi settings and add the printer by selecting its network.\n3. Use the "Standard" or "Easy" method as suggested in your printer application or guide provided in the manual.\n\n\nIf you continue to experience issues, please reply with any error messages displayed. We are here to help. \n\n\nBest regards,\nTech Online Store Support Team'],
#        ['Help Needed: Printer Connection Problem',
#         'Hi <name>,\n\n\nWe appreciate you contacting us. To assist you with the connectivity issue of your HP DeskJet 3755 printer, please follow these steps: 1) Power cycle your printer and router. 2) Make sure your printer is located within range of the wireless network. 3) Carefully re-enter your Wi-Fi credentials. 4) Check for printer driver updates. 5) Utilize the HP Print and Scan Doctor tool for diagnostic purposes. If the issue continues, please inform us for further assistance.\n\n\nBest wishes,\nCustomer Support'],
#        ['Request for Printer Exchange',
#         'Dear <name>,\n\n\nThank you for reaching out about your Canon PIXMA MG3620 printer. We apologize for the inconvenience with frequent paper jams. To assist you with an exchange, please ensure that the printer is within the warranty period and that you have the original packaging available. Forward a copy of your purchase receipt to our returns department, mentioning Order No. <acc_num>. Our team will coordinate the exchange process and contact you via <tel_num> for further instructions.\n\n\nBest regards,\nTech Online Store Support'],
#        ['Help Needed for Printer Connection Issue',
#         "Subject: Re: Help Needed for Printer Connection Issue\n\n\nHello <name>,\n\n\nTo resolve the network connectivity issue with your Epson EcoTank ET-4760, please try the following steps: \n\n\n1. Ensure your Wi-Fi is enabled and the printer is within range.\n2. Restart both the printer and router.\n3. Check the printer's network settings for correct Wi-Fi credentials.\n4. Update the printer’s firmware.\n\n\nIf the issue persists, feel free to contact us for further assistance.\n\n\nBest regards,\n[Your Name]  \nService Desk Agent"],
#        ['Wi-Fi Connectivity Issues with Canon PIXMA MG3620 Printer',
#         "Dear <name>,\n\n\nThank you for reaching out regarding the Wi-Fi connectivity issues with your Canon PIXMA MG3620 printer. Please try the following troubleshooting steps:\n\n\n1. Restart your printer and router to refresh the connection.\n2. Ensure the printer is within the range of the Wi-Fi signal and that no physical obstructions are blocking the signal.\n3. Confirm that the printer’s firmware is up-to-date; you can usually do this through the printer's settings menu.\n4. Check the Wi-Fi network name (SSID) and password to make sure they are correct.\n5. Re-add the printer to your network: go to the printer's Wi-Fi settings, disconnect from the current network, and then reconnect.\n\n\nIf these steps don't resolve the issue, you may need to consider a factory reset of the printer's network settings or contact Canon support for further assistance.\n\n\nBest regards,\nService Desk Agent"],
#        ['Issue with Canon PIXMA MG3620 Wi-Fi Connection',
#         "Subject: Re: Issue with Canon PIXMA MG3620 Wi-Fi Connection\n\n\nHello <name>,\n\n\nThank you for reaching out. Let's try a few steps to resolve the Wi-Fi connectivity issue with your Canon PIXMA MG3620 printer. \n\n\n1. **Restart the Devices**: Power off your printer, router, and the device you print from, wait for a minute, and restart them.\n\n\n2. **Re-establish Wi-Fi Connection**: On the printer panel, press the Wi-Fi button until it starts to blink. Follow the steps from your manual to reconnect it to your network.\n\n\n3. **Network Environment**: Make sure the printer is within range of the Wi-Fi signal and there are no obstructions or interference from other electronic devices.\n\n\n4. **Update Firmware**: Check if your printer’s firmware is up to date. You can do this on the Canon support website.\n\n\n5. **Reinstall Drivers**: Reinstall the printer drivers on your computer, preferably the latest version from the Canon website.\n\n\nIf the problem persists, please contact our support team with the printer model and errors observed for further troubleshooting. You can reach us at <tel_num> for direct assistance.\n\n\nWe are here to help resolve your issue promptly.\n\n\nBest regards,\nTech Online Store Support Team"]],
#       dtype=object)

# %%
#AWS, Printer,Cisco Router ISR4331,Dell XPS 13

# %%
df_eng.loc[[935, 472, 732, 39], ["subject", "body", "answer"]].values
# Out:
# array([['Company Network Issue',
#         "Dear Customer Support,\n\n\nI am writing to report an issue with our Cisco Router ISR4331 at our headquarters. We are experiencing intermittent connection drops which are frequently disrupting our company's network activities. This issue has become increasingly problematic, affecting our daily operations and causing significant inconvenience. Our IT department has verified the problem is not sourced from our end. We would appreciate it if your team could provide us with a solution or suggest the next steps for troubleshooting. Your prompt attention to this matter would be highly appreciated.\n\n\nThank you,\n<name>\nIT Department\n<name> Ltd.",
#         'Subject: Re: Company Network Issue\n\n\nDear <name>,\n\n\nThank you for reaching out about the issue with your Cisco Router ISR4331. We apologize for any disruptions this has caused. Our technical team is reviewing connectivity logs to identify the root cause of the intermittent connection drops you are experiencing. We recommend ensuring the router firmware is up-to-date and checking for any configurations that might contribute to instability.\n\n\nIf the problem persists, please let us know, and we can arrange for a specialist to further diagnose the issue remotely or visit your location if necessary. We appreciate your patience and are committed to resolving this swiftly.\n\n\nBest regards,\n<name>\nCustomer Support Team\n<name> Services'],
#        ['Urgent: Critical Network Issue with Router ISR4331',
#         'Dear Support Team, \n\n\nI am writing to report a high-priority incident involving our Cisco Router ISR4331. Our network has been experiencing frequent dropouts, significantly affecting our enterprise connectivity. This issue impacts our operations, and we need urgent assistance to resolve it as soon as possible.\n\n\nThe disruption in connectivity is causing delays and inefficiencies, impacting overall productivity. After multiple attempts to diagnose internally, we have been unable to pinpoint the root cause of the problem. Therefore, we seek your expert assistance in resolving this matter. \n\n\nWe have logged this incident as urgent and would appreciate a prompt response outlining your next steps or any immediate actions we can take in the interim. Please coordinate this matter with our IT head, <name>, who can be reached at <tel_num>. \n\n\nThank you for your immediate attention to this matter.\n\n\nSincerely,\n\n\n<name>\n<position>\n<company>',
#         "Dear <name>,\n\n\nThank you for contacting us regarding the critical network issue with your Cisco Router ISR4331. We understand the urgency and the impact it is having on your operations.\n\n\nOur team is ready to assist with this high-priority incident. We recommend checking the router's firmware for updates which could resolve connectivity issues, and confirming that all cables and connections are secure. Additionally, restarting the router can help in some cases to restore network stability.\n\n\nPlease provide any error logs if available, which could help our analysis. Meanwhile, we have scheduled a specialist to contact <name>, your IT head, at <tel_num> today to discuss further steps and arrange a more in-depth investigation.\n\n\nWe are committed to resolving this issue swiftly and efficiently. Please let us know if there is any other assistance you require.\n\n\nKind regards,\n\n\n<Service Desk Agent Name>\nService Support Team\n<Company Name>"],
#        ['Problems with Network Stability',
#         'The Cisco Router ISR4331 often experiences connection drops, obstructing vital communication during company conferences.',
#         "Thank you for contacting us. We recommend updating the router's firmware and checking for any recent changes in its settings. If the issue persists, please contact support for further troubleshooting."],
#        ['Urgent: Cisco Router ISR4331 Network Connectivity Issues',
#         'Dear Customer Support Team,\n\n\nI hope this message finds you well. I am writing to formally bring to your attention an issue regarding the network connectivity of my Cisco Router ISR4331. My name is <name>, and I have been consistently experiencing problems for the past couple of weeks. The device, which was recommended to me for its reputed high performance, is unfortunately not delivering as expected.\n\n\nThe primary issue is that the router fails to maintain a consistent network speed, and frequently drops the connection. This has significantly disrupted my work from home arrangements, where reliable internet connectivity is crucial. Initially, I thought this might be related to my internet service provider, but after several checks and consultations with them, it has been confirmed that the problem is not on their end.\n\n\nTo provide more specifics, the connection seems to drop unpredictably, sometimes even multiple times within the same hour, and during these times, no particular activity is being performed that could overwhelm the network. I have already tried basic troubleshooting steps such as restarting the router, resetting it to factory settings, and updating the firmware. None of these measures have yielded any positive outcome.\n\n\nGiven these circumstances, I kindly request your assistance to resolve this situation at your earliest convenience. Perhaps there might be an advanced setting or configuration change that could stabilize the network performance of the ISR4331. Your expert guidance and support in resolving this matter would be invaluable.\n\n\nThank you for your attention to this issue. Please let me know if you require any additional information or if there are specific details about the setup you need to assist further.\n\n\nKind regards,\n\n\n<name>\n<tel_num>\n<acc_num>',
#         "Dear <name>,\n\n\nThank you for reaching out to us regarding the connectivity issues with your Cisco Router ISR4331. We understand the importance of reliable network performance and we are here to help.\n\n\nBased on the information you provided, you've already taken significant steps to troubleshoot the issue. We recommend checking these additional points:\n\n\n1. **Check Cables and Connections**: Ensure that all cables are securely connected and undamaged.\n2. **Check Router Placement**: Place your router in a central location, free from obstructions, to improve signal strength.\n3. **Disable QoS**: Sometimes disabling Quality of Service (QoS) can stabilize speeds.\n4. **Check for Interference**: Consider potential interference from other electronic devices and try changing the wireless channel.\n\n\nIf these don't improve the situation, please reach out with the router logs and any error messages you may have observed, and we'll investigate further. \n\n\nFeel free to contact us at your convenience for further assistance. We aim to resolve this promptly so you can resume your normal work activities.\n\n\nBest regards,\n\n\nCustomer Support Team"]],
#       dtype=object)

# %%
df_eng.loc[[690,1129,928,5,506], ["subject", "answer"]].values
# Out:
# array([['Immediate Assistance Required: Touchscreen Not Responding Problem',
#         "Dear <name>,\n\n\nWe appreciate you contacting us regarding the unresponsive touchscreen issue with your Microsoft Surface Pro 7. We apologize for the trouble you have faced, particularly as your device is crucial for both personal and professional usage.\n\n\nTo resolve the problem, please follow these steps:\n1. Execute a two-button shutdown by simultaneously pressing and holding the power button along with the volume-up button for approximately 15 seconds, then release them. Afterward, wait a few seconds and turn the device back on.\n2. Utilize the Surface Diagnostic Toolkit available on Microsoft's website, which can automatically identify and frequently fix prevalent issues.\n3. Confirm through Windows Update that the latest device drivers are correctly installed.\n\n\nIf these measures do not rectify the issue, your device may need further examination to assess any possible hardware defects. Please let us know if you require guidance on arranging an in-person assessment or repair service.\n\n\nDue to the urgency, your case will be prioritized. Do not hesitate to share any further details that may expedite the process.\n\n\nWe value your patience and look forward to resolving this matter as quickly as possible.\n\n\nSincerely,\n\n\n<name of service desk agent>\nTech Online Store Support Team"],
#        ['Assistance needed for MacBook Air M1 keyboard',
#         "Dear <name>,\n\n\nThank you for contacting Tech Online Store Customer Support. I'm sorry to hear about the keyboard issue with your MacBook Air M1.\n\n\nTo resolve this, we recommend trying to reset the System Management Controller (SMC) as an additional troubleshooting step. If the problem remains unsolved, your keyboard may require servicing.\n\n\nPlease visit our nearest service center or contact us to arrange an inspection and repair. If your device is under warranty, the repair may be covered. Keep your account number <acc_num> and device serial number handy for assistance.\n\n\nFeel free to call us at <tel_num> for further support. We are here to help.\n\n\nBest regards,\nTech Online Store Customer Support"],
#        ['Dell XPS 13 Overheating Issue',
#         "Hello,\n\n\nThank you for reaching out and bringing this issue to our attention. I'm sorry to hear about the overheating problem with your Dell XPS 13 9310 laptop. Let's work together to resolve this.\n\n\nFirst, ensure that the laptop's vents are clean and unobstructed for optimal airflow. You might also try using the laptop on a hard, flat surface or consider a cooling pad to help dissipate heat. Additionally, reverting any recent driver updates could help determine if a software change caused the issue.\n\n\nIf the overheating continues, it might be necessary to have the hardware checked. Please provide your purchase details and warranty information, and we can assist in arranging a professional evaluation or repair.\n\n\nFeel free to reach out if you need further assistance. We're here to help you get back to seamless working conditions as soon as possible.\n\n\nBest regards,\nTech Online Store Customer Support"],
#        ['Exchange Request for Malfunctioning Dell XPS 13',
#         "Dear <name>,\n\n\nThank you for reaching out and bringing this issue to our attention. We apologize for the inconvenience you've experienced with your Dell XPS 13 9310. Based on your order number <order_num>, we confirm that you are eligible for an exchange under our store's policy.\n\n\nTo proceed, please follow these steps:\n1. Return the faulty device using the provided prepaid shipping label included in your package.\n2. Ensure all original packaging and components are included in the return.\n3. Once we receive and verify the item, we will process the exchange and send you a new Dell XPS 13 9310 unit.\n\n\nYou can track your return through your online account on our website. We aim to make this process as smooth as possible and will notify you once the replacement is on its way.\n\n\nIf you need further assistance, feel free to contact us directly.\n\n\nThank you for your patience and understanding.\n\n\nSincerely,\nTech Online Store Customer Support"],
#        ['High CPU Usage Issue: Dell XPS 13 9310',
#         "Dear <name>,\n\n\nThank you for reaching out and bringing this matter to our attention. I'm sorry to hear about the issues you're experiencing with your Dell XPS 13 9310.\n\n\nTo address high CPU usage, please try the following steps:\n\n\n1. **Check Background Processes:** Ensure unnecessary background processes are disabled. You can do this through Task Manager.\n2. **Run System Diagnostics:** Use Dell SupportAssist to run diagnostics and check for hardware issues.\n3. **Cooling and Ventilation:** Make sure the laptop is on a hard, flat surface for optimal airflow.\n4. **BIOS/Driver Updates:** Verify that all drivers and BIOS are up to date by visiting Dell's official support page.\n\n\nIf the problem persists after these steps, I recommend scheduling a service under your warranty. Our technicians will evaluate your device for a potential repair or replacement solution.\n\n\nPlease reach out directly to our technical support team at <customer_support_email> or call us at our helpline <support_tel_num> for further assistance. \n\n\nWe're here to resolve this issue promptly so you can get back to uninterrupted productivity. \n\n\nThank you for your patience and cooperation.\n\n\nBest regards,\n\n\nCustomer Support Team\nTech Online Store"]],
#       dtype=object)

# %%
# prompt: use sentence embedder to embedd tickets

# !pip install sentence-transformers

from sentence_transformers import SentenceTransformer

model = SentenceTransformer('all-mpnet-base-v2')

# Assuming 'tickets' is your Series containing the text of the tickets
# Example (replace with your actual tickets data):
# tickets = df_eng.loc[:, ["body", "answer"]].apply(lambda x: f"Body: {x['body']} \n\n\n Answer: {x['answer']}", axis=1)

# Generate embeddings
embeddings = model.encode(tickets.tolist())

# Now 'embeddings' is a NumPy array where each row is the embedding of a ticket.
print(embeddings.shape) # Print the shape of the embedding matrix
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (3.3.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.47.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (2.5.1+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.6.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.27.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.12.14)
# (339, 768)

# %%
# prompt: get pc1, 2 3 for ticket_embeddings, and plot a plotly express 3d

import plotly.express as px

# Assuming 'embeddings' is a NumPy array of ticket embeddings and 'pca_df' already exists
pca = PCA(n_components=3)
ticket_embeddings_pca = pca.fit_transform(embeddings)
pca_df = pd.DataFrame(data=ticket_embeddings_pca, columns=['PC1', 'PC2', 'PC3'])

fig = px.scatter_3d(pca_df, x='PC1', y='PC2', z='PC3', color=df_eng['combined_tags'] ,title='3D Scatter Plot of Ticket Embeddings')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="895b0bab-873f-4631-a32b-9ea350300c9b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("895b0bab-873f-4631-a32b-9ea350300c9b")) {                    Plotly.newPlot(                        "895b0bab-873f-4631-a32b-9ea350300c9b",                        [{"hovertemplate":"color=Service Outage Network Issue Urgent Issue Technical Support Problem Resolution Critical Failure System Crash Service Disruption \u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003ePC3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Service Outage Network Issue Urgent Issue Technical Support Problem Resolution Critical Failure System Crash Service Disruption ","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Service Outage Network Issue Urgent Issue Technical Support Problem Resolution Critical Failure System Crash Service Disruption ","scene":"scene","showlegend":true,"x":[-0.28175437],"y":[0.51431745],"z":[-0.10798269],"type":"scatter3d"},{"hovertemplate":"color=Technical Support Product Support Hardware Failure Problem Resolution Urgent Issue Service Recovery Documentation Request  \u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003ePC3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Technical Support Product Support Hardware Failure Problem Resolution Urgent Issue Service Recovery Documentation Request  ","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Technical Support Product Support Hardware Failure Problem Resolution Urgent Issue Service Recovery Documentation Request  ","scene":"scene","showlegend":true,"x":[-0.22035341],"y":[-0.24969885],"z":[0.06407486],"type":"scatter3d"},{"hovertemplate":"color=Returns and Exchanges Product Replacement Customer Service Technical Support Order Issue    \u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003ePC3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Returns and Exchanges Product Replacement Customer Service Technical Support Order Issue    ","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Returns and Exchanges Product Replacement Customer Service Technical Support Order Issue    ","scene":"scene","showlegend":true,"x":[0.0012976439],"y":[-0.31255493],"z":[0.09172985],"type":"scatter3d"},{"hovertemplate":"color=Technical Support IT Support Performance Tuning Problem Resolution Technical Guidance Service Recovery   \u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003ePC3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Technical Support IT Support Performance Tuning Problem Resolution Technical Guidance Service Recovery   ","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Technical Support IT Support Performance Tuning Problem Resolution Technical Guidance Service Recovery   ","scene":"scene","showlegend":true,"x":[0.32226333],"y":[0.19369651],"z":[0.34809205],"type":"scatter3d"},{"hovertemplate":"color=Service Outage Urgent Issue IT Support System Maintenance Incident Report Customer Service   \u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003ePC3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Service Outage Urgent Issue IT Support System Maintenance Incident Report Customer Service   ","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Service Outage Urgent Issue IT Support System Maintenance Incident Report Customer Service   ","scene":"scene","showlegend":true,"x":[0.39395604],"y":[0.10945442],"z":[-0.25360972],"type":"scatter3d"},{"hovertemplate":"color=Technical Support Software Bug Urgent Issue Problem Resolution Customer Service Technical Guidance   \u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2= ...

# %%
df_eng.index
# Out:
# Index([   0,    1,    5,    6,    7,    8,   11,   13,   18,   20,
#        ...
#        1435, 1440, 1447, 1498, 1512, 1517, 1528, 1536, 1537, 1561],
#       dtype='int64', length=339)

# %%
# prompt: use ner model on subject, to get out nouns

# !pip install spacy
# !python -m spacy download en_core_web_sm

import spacy

# Load the English language model
nlp = spacy.load("en_core_web_sm")

# Example usage with a subject from your DataFrame
subjects = df_eng["subject"].tolist()

for subject in subjects:
  doc = nlp(subject)
  nouns = [token.text for token in doc if token.pos_ == "NOUN"]
  print(f"Subject: {subject}")
  print(f"Nouns: {nouns}")
  print("-" * 20)
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.11/dist-packages (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.5.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.15.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.10.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.1.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.12.14)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 85.0 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.11/dist-packages (from en-core-web-sm==3.7.1) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.5.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.15.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.10.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.12.14)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.17.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# Subject: Urgent: Critical impact on enterprise network connectivity
# Nouns: ['impact', 'enterprise', 'network', 'connectivity']
# --------------------
# Subject: Intermittent Cursor Freezing Issue on Dell XPS
# Nouns: []
# --------------------
# Subject: Exchange Request for Malfunctioning Dell XPS 13
# Nouns: ['Request']
# --------------------
# Subject: Request for Server Administration Assistance
# Nouns: ['Request']
# --------------------
# Subject: Immediate Attention Required: AWS Outage Concern
# Nouns: ['Concern']
# --------------------
# Subject: Urgent Assistance Needed
# Nouns: []
# --------------------
# Subject: Bug Report: UI Bug in React App
# Nouns: ['Bug', 'Report', 'Bug']
# --------------------
# Subject: Urgent: AWS Web Access Issue Resolution Required
# Nouns: ['Web']
# --------------------
# Subject: Issues with AWS Resource Optimization
# Nouns: ['Issues']
# --------------------
# Subject: Issues Setting Up AWS EC2 Security Group
# Nouns: ['Issues']
# --------------------
# Subject: Urgent Request for Assistance
# Nouns: ['Request', 'Assistance']
# --------------------
# Subject: Assistance Needed for Canon Setup
# Nouns: ['Assistance']
# --------------------
# Subject: Urgent: AWS Management Service Issues
# Nouns: []
# --------------------
# Subject: Urgent Care Needed: Issue with AWS Deployment
# Nouns: ['Issue']
# --------------------
# Subject: Double Billing Issue on Purchase
# Nouns: ['Issue']
# --------------------
# Subject: Assistance Required: Printer Connectivity Issue
# Nouns: ['Assistance', 'Issue']
# --------------------
# Subject: Urgent: Cisco Router ISR4331 Network Connectivity Issues
# Nouns: ['ISR4331', 'Issues']
# --------------------
# Subject: Urgent: Immediate Resolution Required for AWS Downtime
# Nouns: []
# --------------------
# Subject: Urgent AWS Connectivity Issue
# Nouns: ['Issue']
# --------------------
# Subject: Urgent: User unable to join scheduled Zoom meeting
# Nouns: ['User', 'meeting']
# --------------------
# Subject: Request for urgent assistance with Dell XPS 13 issues
# Nouns: ['Request', 'assistance', 'issues']
# --------------------
# Subject: Microsoft Surface Pro 7 Touchscreen Issue - Urgent Attention Required
# Nouns: []
# --------------------
# Subject: Wi-Fi Connectivity Issues with Canon PIXMA MG3620 Printer
# Nouns: ['Issues']
# --------------------
# Subject: IT Consulting Inquiry
# Nouns: []
# --------------------
# Subject: Urgent Assistance Needed for Zoom Issues
# Nouns: ['Issues']
# --------------------
# Subject: Connectivity Issues
# Nouns: ['Issues']
# --------------------
# Subject: Urgent: Dell XPS 13 9310 Laptop Not Powering On
# Nouns: ['Laptop']
# --------------------
# Subject: Assistance Needed for Canon PIXMA MG3620 Print Quality Issue
# Nouns: ['Assistance']
# --------------------
# Subject: Urgent: MySQL Database Configuration Issue
# Nouns: []
# --------------------
# Subject: Issues with AWS Management Service Deployment
# Nouns: ['Issues']
# --------------------
# Subject: Intermittent Connectivity Issues with Cisco Router
# Nouns: []
# --------------------
# Subject: Intermittent connectivity on ISR4331
# Nouns: ['connectivity', 'ISR4331']
# --------------------
# Subject: Request for Configuration Changes
# Nouns: ['Request', 'Configuration', 'Changes']
# --------------------
# Subject: Urgent Resolution Needed: VS Code Crashing
# Nouns: []
# --------------------
# Subject: High Priority Incident: Immediate AWS Deployment Resolution Needed
# Nouns: []
# --------------------
# Subject: Inquiry Regarding Updates on AWS Services
# Nouns: ['Inquiry', 'AWS', 'Services']
# --------------------
# Subject: Scheduled Maintenance Notice
# Nouns: []
# --------------------
# Subject: Missing ticket notifications impacting Jira feedback
# Nouns: ['ticket', 'notifications', 'feedback']
# --------------------
# Subject: Request for Setup Assistance with HP DeskJet 3755
# Nouns: ['Request']
# --------------------
# Subject: Urgent Update Required for Jira Software 8.20
# Nouns: []
# --------------------
# Subject: MacBook Air M1 Power Issue
# Nouns: []
# --------------------
# Subject: Urgent: Issues with AWS Management Service
# Nouns: ['Issues']
# --------------------
# Subject: Inquiry About JavaScript React Development Service
# Nouns: ['Inquiry']
# --------------------
# Subject: Guidance Needed for IT Infrastructure Efficiency
# Nouns: ['Guidance']
# --------------------
# Subject: Intermittent Network Connectivity Issues
# Nouns: ['Issues']
# --------------------
# Subject: Urgent: Dell XPS 13 overheating and battery drain issue
# Nouns: ['battery', 'drain', 'issue']
# --------------------
# Subject: Screen Flickering Issue on Surface Pro 7
# Nouns: ['Issue']
# --------------------
# Subject: Inquiry: MacBook Air M1 Graphic Design Software Compatibility
# Nouns: ['Inquiry']
# --------------------
# Subject: Inquiry about Dell XPS 13 9310 issues
# Nouns: ['Inquiry', 'issues']
# --------------------
# Subject: Issue with Surface Pro 7 - Screen Flickering
# Nouns: ['Issue', 'Flickering']
# --------------------
# Subject: Issue with Dell XPS 13 9310 Performance
# Nouns: ['Issue', 'Performance']
# --------------------
# Subject: Urgent Support Required: Battery Issues with MacBook Air M1
# Nouns: ['Issues']
# --------------------
# Subject: Oracle Database 19c Connectivity Issue
# Nouns: ['19c', 'Issue']
# --------------------
# Subject: Urgent Router Issue
# Nouns: []
# --------------------
# Subject: Concerns regarding MacBook Air M1 battery performance
# Nouns: ['Concerns', 'battery', 'performance']
# --------------------
# Subject: Immediate Fix Needed for Jira Crashes
# Nouns: []
# --------------------
# Subject: Assistance Required: Issue with Adobe Photoshop 2024 Installation
# Nouns: ['Assistance', 'Issue', 'Installation']
# --------------------
# Subject: Frequent audio issues with Zoom application
# Nouns: ['issues', 'application']
# --------------------
# Subject: Urgent: Epson EcoTank ET-4760 Paper Jam Issue
# Nouns: []
# --------------------
# Subject: Assistance Required for Amazon Navigation
# Nouns: ['Assistance']
# --------------------
# Subject: Request for billing details and payment options assistance
# Nouns: ['Request', 'billing', 'details', 'payment', 'options', 'assistance']
# --------------------
# Subject: Urgent Server Admin Interface Issue
# Nouns: ['Issue']
# --------------------
# Subject: Database Design Change Request
# Nouns: ['Request']
# --------------------
# Subject: Screen Flickering Issue
# Nouns: ['Flickering', 'Issue']
# --------------------
# Subject: Assistance Needed
# Nouns: ['Assistance']
# --------------------
# Subject: Support Request for Cisco Router ISR4331
# Nouns: ['Request', 'ISR4331']
# --------------------
# Subject: High-Priority Problem
# Nouns: []
# --------------------
# Subject: Billing Issues on AWS Services
# Nouns: ['Billing', 'Issues', 'AWS', 'Services']
# --------------------
# Subject: Inquiry Regarding Microsoft Surface Pro 7 Purchase
# Nouns: ['Inquiry', 'Purchase']
# --------------------
# Subject: Request for Guidance: Optimizing Server Configurations
# Nouns: ['Request', 'Guidance']
# --------------------
# Subject: Urgent: Frequent PostgreSQL Server Crashes
# Nouns: ['PostgreSQL']
# --------------------
# Subject: Connectivity Issues with Cisco Router
# Nouns: ['Connectivity', 'Issues']
# --------------------
# Subject: Immediate Assistance Needed
# Nouns: []
# --------------------
# Subject: Urgent: Assistance Needed for MySQL 8.0.30 Data Loss Recovery
# Nouns: ['Assistance']
# --------------------
# Subject: Urgent Wireless Printing Issue Resolution
# Nouns: []
# --------------------
# Subject: Urgent: Netgear Switch GS108 Connectivity Issue
# Nouns: ['GS108', 'Issue']
# --------------------
# Subject: Assistance Needed for Printer Setup
# Nouns: ['Assistance']
# --------------------
# Subject: Request for Change in AWS Configurations for Optimization
# Nouns: ['Request', 'Optimization']
# --------------------
# Subject: Urgent Resolution Required
# Nouns: []
# --------------------
# Subject: Login Issues with Microsoft Surface Pro 7
# Nouns: []
# --------------------
# Subject: Urgent: Service Outage During Scheduled Maintenance
# Nouns: []
# --------------------
# Subject: Jira Software Efficiency Issue
# Nouns: ['Issue']
# --------------------
# Subject: Excel Intermittent Crashing Issue
# Nouns: []
# --------------------
# Subject: Immediate Support Required
# Nouns: []
# --------------------
# Subject: Google Workspace
# Nouns: []
# --------------------
# Subject: Required Modifications for IT Ticket System Pipeline
# Nouns: []
# --------------------
# Subject: Request for Assistance with Wireless Printing
# Nouns: ['Request', 'Assistance']
# --------------------
# Subject: Exchange Request for Canon PIXMA MG3620 Due to Print Quality Issues
# Nouns: ['Request']
# --------------------
# Subject: Issue with HP DeskJet 3755 Connection
# Nouns: ['Issue', 'Connection']
# --------------------
# Subject: Surface Pro 7 Issue
# Nouns: ['Issue']
# --------------------
# Subject: Request for Change in AWS Management Configuration
# Nouns: ['Request']
# --------------------
# Subject: Malfunctioning LG OLED C1 Display Issue
# Nouns: []
# --------------------
# Subject: Assistance Needed: Reset Password for Office 365
# Nouns: ['Assistance']
# --------------------
# Subject: Immediate Help Required for Server Outage Situation
# Nouns: ['Help']
# --------------------
# Subject: Slack 4.23.0 Issues
# Nouns: ['Slack', 'Issues']
# --------------------
# Subject: Urgent License Error
# Nouns: []
# --------------------
# Subject: MacBook Air M1 Overheating Issues During Use
# Nouns: ['Use']
# --------------------
# Subject: Guidance on IT Consulting Services
# Nouns: ['Guidance']
# --------------------
# Subject: Ticket Raised: AWS Resources Misconfiguration Issue
# Nouns: ['Ticket']
# --------------------
# Subject: Performance Issue with Dell XPS 13 9310 Demo
# Nouns: ['Performance', 'Demo']
# --------------------
# Subject: Frequent Disconnect Issues with Cisco Router ISR4331
# Nouns: ['Issues', 'ISR4331']
# --------------------
# Subject: Urgent Request for Jira Ticket Modification
# Nouns: ['Request']
# --------------------
# Subject: Request for Change in User Permissions Setup
# Nouns: ['Request']
# --------------------
# Subject: Inquiry for Professional Support
# Nouns: ['Inquiry']
# --------------------
# Subject: Urgent: Ticket System Errors
# Nouns: ['Ticket', 'Errors']
# --------------------
# Subject: Intermittent Network Issues
# Nouns: ['Issues']
# --------------------
# Subject: Request for Exchange: Faulty MacBook Air M1 After Use
# Nouns: ['Request']
# --------------------
# Subject: Request for exchange due to connectivity issues
# Nouns: ['Request', 'exchange', 'connectivity', 'issues']
# --------------------
# Subject: Request for Optimization of AWS Cloud Resources and Stability
# Nouns: ['Request']
# --------------------
# Subject: Printer Setup Assistance
# Nouns: ['Assistance']
# --------------------
# Subject: Touchscreen and Keyboard Issues with Surface Pro 7
# Nouns: []
# --------------------
# Subject: Urgent Help Needed: Adobe Photoshop 2024 Access Issue
# Nouns: ['Help', 'Issue']
# --------------------
# Subject: Urgent AWS Optimization
# Nouns: ['Optimization']
# --------------------
# Subject: Urgent Assistance Needed for AWS Access Issue
# Nouns: ['Issue']
# --------------------
# Subject: Dell XPS 13 9310 Issues
# Nouns: ['Issues']
# --------------------
# Subject: Cisco Router Outage
# Nouns: []
# --------------------
# Subject: Immediate Assistance Required
# Nouns: []
# --------------------
# Subject: Urgent Issue: Email Access in Office 365
# Nouns: []
# --------------------
# Subject: Inquiry About Epson EcoTank ET-4760 Printer
# Nouns: ['Inquiry']
# --------------------
# Subject: Urgent: Issue Connecting to PostgreSQL Database
# Nouns: ['Issue']
# --------------------
# Subject: Jira Workflow Update
# Nouns: []
# --------------------
# Subject: Urgent Issue
# Nouns: []
# --------------------
# Subject: Urgent: Frequent Network Drops Issue
# Nouns: []
# --------------------
# Subject: Urgent: Connectivity Issues with Cisco Router ISR4331
# Nouns: ['Issues', 'ISR4331']
# --------------------
# Subject: Update Required: Billing Information for Google Workspace
# Nouns: ['Billing']
# --------------------
# Subject: Billing Issues with Adobe Photoshop
# Nouns: ['Billing', 'Issues']
# --------------------
# Subject: Issue with Microsoft Surface Pro 7
# Nouns: ['Issue']
# --------------------
# Subject: Request for Detailed Information on React Services
# Nouns: ['Request']
# --------------------
# Subject: Software Update Request
# Nouns: ['Request']
# --------------------
# Subject: Excel Version Update Request
# Nouns: ['Request']
# --------------------
# Subject: AWS Management Service Inquiry
# Nouns: []
# --------------------
# Subject: Assistance with IT Consultancy Options
# Nouns: ['Assistance']
# --------------------
# Subject: Questions About Printer Replacement
# Nouns: ['Questions']
# --------------------
# Subject: High Priority Request for Assistance
# Nouns: ['Request', 'Assistance']
# --------------------
# Subject: Network Outage Due to Cisco Router ISR4331 Failure
# Nouns: []
# --------------------
# Subject: Urgent Assistance Needed for Ticket System
# Nouns: ['Ticket', 'System']
# --------------------
# Subject: Network Connectivity Challenges Occurring Intermittently
# Nouns: ['Network']
# --------------------
# Subject: High Priority: Delay in Server Setup Disrupting Client Activities
# Nouns: ['Activities']
# --------------------
# Subject: Screen Flickering Issue on Dell XPS 13
# Nouns: ['Issue']
# --------------------
# Subject: Request for Refund Due to Incorrect Billing
# Nouns: ['Request']
# --------------------
# Subject: Request for Product Exchange Due to Connectivity Issues
# Nouns: ['Request', 'Issues']
# --------------------
# Subject: Network Configuration Issue
# Nouns: []
# --------------------
# Subject: Inquiry About Features and Pricing Options for React
# Nouns: ['Inquiry']
# --------------------
# Subject: Immediate AWS Assistance
# Nouns: ['Assistance']
# --------------------
# Subject: Inquiry on Jira 8.20 Assistance
# Nouns: ['Inquiry', 'Assistance']
# --------------------
# Subject: Recurrent Excel Crash Issue Post Update
# Nouns: ['Recurrent']
# --------------------
# Subject: Urgent: AWS deployment issue
# Nouns: ['deployment', 'issue']
# --------------------
# Subject: Request for Jira Software Enhancements
# Nouns: ['Request', 'Enhancements']
# --------------------
# Subject: Service Charge Clarification
# Nouns: ['Service']
# --------------------
# Subject: Error with Slack Channel Integration
# Nouns: ['Error']
# --------------------
# Subject: Assistance Required: Email Configuration Issue
# Nouns: ['Assistance']
# --------------------
# Subject: Inquiry on Samsung QLED TV Features
# Nouns: ['Inquiry', 'TV', 'Features']
# --------------------
# Subject: AWS Cost Optimization Help
# Nouns: ['Help']
# --------------------
# Subject: Internet Connectivity Issues
# Nouns: ['Internet', 'Issues']
# --------------------
# Subject: Urgent Cisco Router Issue
# Nouns: []
# --------------------
# Subject: Urgent Assistance Needed on Billing Error
# Nouns: []
# --------------------
# Subject: Immediate Support Required for Connectivity Issues
# Nouns: ['Issues']
# --------------------
# Subject: Request for Server Configuration Changes
# Nouns: ['Request']
# --------------------
# Subject: Critical: Significant AWS Service Disruption
# Nouns: []
# --------------------
# Subject: Frequent Printer Issues
# Nouns: ['Issues']
# --------------------
# Subject: Critical: Recurring Network Disruption Problem
# Nouns: []
# --------------------
# Subject: Request for Product Exchange - Faulty Battery
# Nouns: ['Request']
# --------------------
# Subject: Battery Issue with Surface Pro
# Nouns: []
# --------------------
# Subject: Assistance Required: Software and Server Issues
# Nouns: ['Assistance']
# --------------------
# Subject: MacBook Air Screen Issue
# Nouns: ['Issue']
# --------------------
# Subject: Request to Return HP DeskJet 3755
# Nouns: ['Request']
# --------------------
# Subject: Boot Issue Assistance
# Nouns: []
# --------------------
# Subject: Network Issues with Cisco Router
# Nouns: ['Issues']
# --------------------
# Subject: Request to Upgrade Microsoft Surface Pro 7
# Nouns: ['Request']
# --------------------
# Subject: MacBook Air Issue
# Nouns: []
# --------------------
# Subject: Urgent: Critical Network Issue with Router ISR4331
# Nouns: ['ISR4331']
# --------------------
# Subject: Issue with Dell XPS 13 overheating
# Nouns: ['Issue']
# --------------------
# Subject: AWS Deployment Issues
# Nouns: ['Issues']
# --------------------
# Subject: Zoom Video Conferencing Issues
# Nouns: ['Issues']
# --------------------
# Subject: Assistance Required for AWS Deployment
# Nouns: ['Assistance']
# --------------------
# Subject: Assistance Required for Epson EcoTank ET-4760 Printer
# Nouns: ['Assistance']
# --------------------
# Subject: Assistance Needed with Wireless Setup for Canon PIXMA MG3620
# Nouns: ['Assistance', 'MG3620']
# --------------------
# Subject: Urgent Excel Macro Issue
# Nouns: []
# --------------------
# Subject: Infrastructure Assistance Request
# Nouns: ['Request']
# --------------------
# Subject: Urgent AWS Support Required
# Nouns: ['Support']
# --------------------
# Subject: Urgent: AWS Management Service Down
# Nouns: []
# --------------------
# Subject: High CPU Usage Issue: Dell XPS 13 9310
# Nouns: ['CPU']
# --------------------
# Subject: Immediate Assistance Required: Visual Studio Code Crashing
# Nouns: []
# --------------------
# Subject: Request for UI Components Update
# Nouns: ['Request']
# --------------------
# Subject: Critical: Problem with AWS Deployment
# Nouns: ['Problem']
# --------------------
# Subject: Request for Cost-Effective AWS Management Solutions
# Nouns: ['Request', 'Cost']
# --------------------
# Subject: Requesting Expert Guidance
# Nouns: []
# --------------------
# Subject: Request for Server Consultation
# Nouns: ['Request']
# --------------------
# Subject: Inquiry About MacBook Air M1 Features
# Nouns: ['Inquiry', 'Features']
# --------------------
# Subject: Request for Printer Exchange
# Nouns: ['Request']
# --------------------
# Subject: Critical: AWS Outage Situation
# Nouns: []
# --------------------
# Subject: Urgent Assistance Needed for Jira Software License Issue
# Nouns: []
# --------------------
# Subject: Urgent Assistance Required for AWS Optimization
# Nouns: ['Optimization']
# --------------------
# Subject: Request for Assistance: Ongoing Surface Pro 7 Issues
# Nouns: ['Request', 'Assistance', 'Issues']
# --------------------
# Subject: Immediate Help Required for Invoicing Mistake
# Nouns: ['Help']
# --------------------
# Subject: Immediate Resolution Required for Server Downtime
# Nouns: []
# --------------------
# Subject: Surface Pro 7 Battery and Overheating Issues
# Nouns: ['Issues']
# --------------------
# Subject: Purchase Inquiry
# Nouns: []
# --------------------
# Subject: Malfunctioning Cisco Router ISR4331 Issue
# Nouns: ['ISR4331']
# --------------------
# Subject: Immediate Attention Needed
# Nouns: []
# --------------------
# Subject: Real-time Messaging Issues
# Nouns: ['time', 'Issues']
# --------------------
# Subject: Assistance Required for Booting Issues
# Nouns: ['Assistance', 'Issues']
# --------------------
# Subject: Urgent Support Inquiry
# Nouns: []
# --------------------
# Subject: Inquiry Regarding MacBook Air M1 Performance
# Nouns: ['Inquiry']
# --------------------
# Subject: Urgent Assistance Required for Server Downtime
# Nouns: []
# --------------------
# Subject: Printer Settings Update Request
# Nouns: ['Request']
# --------------------
# Subject: Assistance with Printer Setup
# Nouns: ['Assistance']
# --------------------
# Subject: Access Issue with Jira Software
# Nouns: ['Access']
# --------------------
# Subject: Urgent Support Needed
# Nouns: []
# --------------------
# Subject: Immediate Assistance Needed with Server Outage
# Nouns: []
# --------------------
# Subject: High Priority Incident: Router Connectivity Issues
# Nouns: ['Issues']
# --------------------
# Subject: Help Needed: Printer Connection Problem
# Nouns: []
# --------------------
# Subject: High-Priority Concern
# Nouns: ['Concern']
# --------------------
# Subject: Urgent: Optimize AWS Infrastructure for Cost Efficiency
# Nouns: ['Optimize', 'Infrastructure', 'Efficiency']
# --------------------
# Subject: Urgent: AWS Downtime Issue
# Nouns: []
# --------------------
# Subject: Urgent: Immediate IT Assistance Needed
# Nouns: []
# --------------------
# Subject: Intermittent Connectivity Issues Report
# Nouns: []
# --------------------
# Subject: IntelliJ IDEA 2024.1 Crashes Post Update
# Nouns: ['Update']
# --------------------
# Subject: Issues with Cisco ISR4331 Router
# Nouns: ['Issues', 'ISR4331', 'Router']
# --------------------
# Subject: Assistance Required: Wireless Connectivity Issue with HP DeskJet 3755
# Nouns: ['Assistance']
# --------------------
# Subject: Urgent: Cisco ISR4331 Issues
# Nouns: ['ISR4331', 'Issues']
# --------------------
# Subject: Urgent: Network Outage
# Nouns: []
# --------------------
# Subject: Urgent Resolution Needed
# Nouns: []
# --------------------
# Subject: Billing Assistance Required
# Nouns: []
# --------------------
# Subject: Network Instability Issue
# Nouns: []
# --------------------
# Subject: Critical Situation
# Nouns: []
# --------------------
# Subject: Immediate Assistance Required: Touchscreen Not Responding Problem
# Nouns: []
# --------------------
# Subject: Urgent: Immediate Review Required on Email Server Configuration
# Nouns: []
# --------------------
# Subject: Incident: Dell XPS 13 9310 Hardware Issue
# Nouns: ['Incident', 'Issue']
# --------------------
# Subject: Assistance Required for HP DeskJet 3755 Paper Jams
# Nouns: ['Assistance', 'Jams']
# --------------------
# Subject: Immediate Attention Required: Connectivity Problem with PostgreSQL Database
# Nouns: ['PostgreSQL']
# --------------------
# Subject: Network Connectivity Issues
# Nouns: ['Issues']
# --------------------
# Subject: Assistance Needed: Jira Software 8.20 Configuration
# Nouns: ['Assistance', 'Configuration']
# --------------------
# Subject: Help Needed: Email Setup Problem
# Nouns: []
# --------------------
# Subject: Issue with Dell XPS 13 Powering On
# Nouns: ['Issue', 'Powering']
# --------------------
# Subject: Billing Inquiry for Service Renewal
# Nouns: []
# --------------------
# Subject: Problems with Network Stability
# Nouns: ['Problems']
# --------------------
# Subject: Request for AWS Service Updates
# Nouns: ['Request', 'Updates']
# --------------------
# Subject: Urgent: Billing Error on MacBook Air M1 Purchase
# Nouns: []
# --------------------
# Subject: Request for Improvements: AWS Infrastructure Settings Update
# Nouns: ['Request', 'Improvements']
# --------------------
# Subject: Critical Server Management Concern
# Nouns: []
# --------------------
# Subject: Performance Issues with MySQL 8.0.30 Database
# Nouns: ['Performance', 'Issues', '8.0.30']
# --------------------
# Subject: Cloud Infrastructure Optimization
# Nouns: []
# --------------------
# Subject: Critical AWS Cost Enhancement
# Nouns: ['AWS', 'Enhancement']
# --------------------
# Subject: New Jira Project Setup
# Nouns: []
# --------------------
# Subject: Critical: Recurring Network Disconnection Problem
# Nouns: []
# --------------------
# Subject: Assistance with AWS Management
# Nouns: ['Assistance', 'Management']
# --------------------
# Subject: Intermittent Connectivity Issues with AWS
# Nouns: ['AWS']
# --------------------
# Subject: Gmail Syncing Issue
# Nouns: []
# --------------------
# Subject: Zoom 5.11.0 Connection Issues
# Nouns: ['Issues']
# --------------------
# Subject: Assistance Required for MacBook Air Activation
# Nouns: ['Assistance']
# --------------------
# Subject: Urgent Support Needed: Dell XPS 13 Issue
# Nouns: ['Issue']
# --------------------
# Subject: Immediate Attention Required
# Nouns: []
# --------------------
# Subject: Urgent: Resolve AWS Infrastructure Downtime Issue
# Nouns: []
# --------------------
# Subject: Upgrade Zoom Request
# Nouns: ['Request']
# --------------------
# Subject: High Priority Request: Server Administration Issues
# Nouns: ['Request', 'Issues']
# --------------------
# Subject: Issues with Cisco Router ISR4331
# Nouns: ['Issues', 'ISR4331']
# --------------------
# Subject: Assistance with Adobe Photoshop
# Nouns: ['Assistance']
# --------------------
# Subject: Urgent IT consulting required for server issues
# Nouns: ['consulting', 'server', 'issues']
# --------------------
# Subject: Urgent AWS Support Needed
# Nouns: ['AWS', 'Support']
# --------------------
# Subject: Request for AWS Infrastructure Scaling Assistance
# Nouns: ['Request']
# --------------------
# Subject: Issue with AWS Billing Charges
# Nouns: ['Issue', 'Charges']
# --------------------
# Subject: Inquiry on MacBook Air M1 availability
# Nouns: ['Inquiry', 'availability']
# --------------------
# Subject: Urgent Request for AWS Infrastructure Optimization
# Nouns: ['Request']
# --------------------
# Subject: Request for Assistance with Office 365 Installation Error
# Nouns: ['Request']
# --------------------
# Subject: Issue with Ticket System
# Nouns: ['Issue', 'Ticket', 'System']
# --------------------
# Subject: Assistance Needed for Epson EcoTank ET-4760 Paper Jams
# Nouns: ['Assistance']
# --------------------
# Subject: Help Needed for Printer Connection Issue
# Nouns: []
# --------------------
# Subject: Immediate Help Required for Billing Discrepancy
# Nouns: ['Help']
# --------------------
# Subject: Urgent: Google Workspace Services Down
# Nouns: []
# --------------------
# Subject: Urgent AWS Deployment Issues
# Nouns: ['Issues']
# --------------------
# Subject: Dell XPS 13 Overheating Issue
# Nouns: ['Issue']
# --------------------
# Subject: Issue with Canon PIXMA MG3620 Wi-Fi Connection
# Nouns: ['Issue', 'Connection']
# --------------------
# Subject: Company Network Issue
# Nouns: []
# --------------------
# Subject: AWS Performance Issues
# Nouns: ['Issues']
# --------------------
# Subject: Issues with IntelliJ IDEA 2024.1 Refactoring Features
# Nouns: ['Issues', 'Features']
# --------------------
# Subject: Immediate Assistance Needed to Resolve Server Outage
# Nouns: []
# --------------------
# Subject: Urgent Issue with AWS Deployment
# Nouns: []
# --------------------
# Subject: Billing Discrepancies
# Nouns: ['Billing', 'Discrepancies']
# --------------------
# Subject: Critical Issue: Network Interruption
# Nouns: []
# --------------------
# Subject: Critical AWS Cost Management
# Nouns: ['AWS']
# --------------------
# Subject: Urgent Support for Laptop Issue
# Nouns: []
# --------------------
# Subject: Billing Discrepancy
# Nouns: []
# --------------------
# Subject: Inquiry About IT Consulting
# Nouns: ['Inquiry']
# --------------------
# Subject: Modification Request: AWS Cost Optimization Strategy
# Nouns: ['Request']
# --------------------
# Subject: Billing Discrepancy Issue
# Nouns: ['Issue']
# --------------------
# Subject: Requesting Support: Router causing network issues
# Nouns: ['Support', 'Router', 'network', 'issues']
# --------------------
# Subject: Investigation into AWS Billing Discrepancy
# Nouns: ['Investigation']
# --------------------
# Subject: Assistance Required for Printer Setup
# Nouns: ['Assistance']
# --------------------
# Subject: Request for Expert Consultation on Ticket System
# Nouns: ['Request', 'Ticket', 'System']
# --------------------
# Subject: Canon PIXMA MG3620 Exchange Request
# Nouns: ['Canon', 'Request']
# --------------------
# Subject: Urgent: Zoom Application Down
# Nouns: ['Application']
# --------------------
# Subject: Immediate Assistance Required for Server Downtime
# Nouns: []
# --------------------
# Subject: High Priority: Zoom Service Outage
# Nouns: []
# --------------------
# Subject: Screen Flickering Issue with Dell XPS 13
# Nouns: ['Issue']
# --------------------
# Subject: Urgent Issue: Ticket System Integration
# Nouns: ['Ticket']
# --------------------
# Subject: Urgent Support Required to Fix Server Downtime
# Nouns: []
# --------------------
# Subject: Assistance needed for MacBook Air M1 keyboard
# Nouns: ['Assistance', 'keyboard']
# --------------------
# Subject: Urgent Assistance Required for AWS Issues
# Nouns: ['Issues']
# --------------------
# Subject: Immediate Assistance Required: Touchscreen Non-Responsive Problem
# Nouns: []
# --------------------
# Subject: Urgent: Major AWS Outage
# Nouns: ['AWS', 'Outage']
# --------------------
# Subject: Urgent Assistance Needed: Cisco ISR4331 Downtime
# Nouns: ['ISR4331']
# --------------------
# Subject: Notification of Planned Maintenance
# Nouns: ['Notification']
# --------------------
# Subject: Frequent Database Downtime Issues
# Nouns: []
# --------------------
# Subject: Urgent Assistance Needed: Issue with AWS Deployment
# Nouns: ['Issue']
# --------------------
# Subject: Request to upgrade IntelliJ IDEA for improved features
# Nouns: ['Request', 'features']
# --------------------
# Subject: Critical Server Management Problem
# Nouns: []
# --------------------
# Subject: Billing Discrepancy with AWS Service
# Nouns: []
# --------------------
# Subject: Request for Expert Assistance
# Nouns: ['Request', 'Assistance']
# --------------------
# Subject: Immediate Resolution Needed: Zoom 5.11.0 Crashes
# Nouns: ['Zoom', 'Crashes']
# --------------------
# Subject: Major Concern
# Nouns: ['Concern']
# --------------------
# Subject: Problems with Network Reliability
# Nouns: ['Problems']
# --------------------
# Subject: Request for IT Consulting Services
# Nouns: ['Request']
# --------------------
# Subject: Urgent: Critical AWS Service Outage Experienced
# Nouns: []
# --------------------
# Subject: AWS Service Update Request
# Nouns: ['Request']
# --------------------
# Subject: Immediate Help Required
# Nouns: []
# --------------------
# Subject: Seeking Assistance: Router Leading to Network Disruptions
# Nouns: ['Assistance']
# --------------------
# Subject: Billing Issue with AWS Management Service
# Nouns: ['Billing']
# --------------------
# Subject: Immediate Support Required: Cisco ISR4331 Router Outage
# Nouns: ['ISR4331']
# --------------------
# Subject: Help with Printer Configuration
# Nouns: []
# --------------------
# Subject: Alert: User Interface Issue in React Application
# Nouns: ['Application']
# --------------------
# Subject: Immediate Support Needed: Touchscreen Non-Responsive Problem
# Nouns: []
# --------------------
# Subject: Urgent Help Needed: AWS Deployment Issue
# Nouns: ['Help', 'Issue']
# --------------------
# Subject: Urgent Support Required for AWS Issue Resolution
# Nouns: []
# --------------------
# Subject: Need Support
# Nouns: ['Support']
# --------------------
# Subject: Request for Changes in AWS Management Dashboard
# Nouns: ['Request']
# --------------------
# Subject: Request for Billing Support
# Nouns: ['Request']
# --------------------
# Subject: High Priority: Recurrent Network Disconnections Problem
# Nouns: []
# --------------------
# Subject: Critical AWS Connection Problem
# Nouns: []
# --------------------
# Subject: Critical Problem
# Nouns: []
# --------------------
# Subject: Urgent: Jira Ticket System Disruption
# Nouns: ['Disruption']
# --------------------
# Subject: Inquiry About Economical AWS Management Alternatives
# Nouns: ['Inquiry']
# --------------------
# Subject: Critical Concern
# Nouns: []
# --------------------
# Subject: Urgent Assistance Required: Issue with AWS Deployment
# Nouns: ['Issue']
# --------------------
# Subject: AWS Authentication Issues
# Nouns: ['Issues']
# --------------------
# Subject: Immediate Assistance Needed: Issues with Server Management
# Nouns: ['Issues']
# --------------------
# Subject: High Priority: Recurring Network Disruptions
# Nouns: ['Disruptions']
# --------------------
# Subject: Request for Support
# Nouns: ['Request', 'Support']
# --------------------
# Subject: Immediate Assistance Requested
# Nouns: []
# --------------------

# %%
# prompt: do clustering on the subject column and make 4 clusters, from them extract issues with thier recurring percentage. import the necesaary library

# Assuming 'embeddings' is your NumPy array of ticket embeddings and df_eng is your DataFrame.
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=4, random_state=42)  # 4 clusters
kmeans.fit(embeddings)
df_eng['cluster'] = kmeans.labels_

# Analyze clusters
issue_percentages = {}
for cluster_id in range(4):
    cluster_data = df_eng[df_eng['cluster'] == cluster_id]
    subject_counts = cluster_data['subject'].value_counts(normalize=True) * 100
    issue_percentages[f'Cluster {cluster_id}'] = subject_counts

    print(f"\nCluster {cluster_id} recurring issues:")
    for issue, percentage in subject_counts.items():
        print(f"- {issue}: {percentage:.2f}%")
# Out:
# Cluster 0 recurring issues:
# - Intermittent Cursor Freezing Issue on Dell XPS: 1.75%
# - Request for Product Exchange - Faulty Battery: 1.75%
# - MacBook Air Screen Issue: 1.75%
# - Boot Issue Assistance: 1.75%
# - Request to Upgrade Microsoft Surface Pro 7: 1.75%
# - MacBook Air Issue: 1.75%
# - Issue with Dell XPS 13 overheating: 1.75%
# - High CPU Usage Issue: Dell XPS 13 9310: 1.75%
# - Inquiry About MacBook Air M1 Features: 1.75%
# - Request for Printer Exchange: 1.75%
# - Request for Assistance: Ongoing Surface Pro 7 Issues: 1.75%
# - Surface Pro 7 Battery and Overheating Issues: 1.75%
# - Purchase Inquiry: 1.75%
# - Assistance Required for Booting Issues: 1.75%
# - Inquiry Regarding MacBook Air M1 Performance: 1.75%
# - Immediate Assistance Required: Touchscreen Not Responding Problem: 1.75%
# - Incident: Dell XPS 13 9310 Hardware Issue: 1.75%
# - Issue with Dell XPS 13 Powering On: 1.75%
# - Urgent: Billing Error on MacBook Air M1 Purchase: 1.75%
# - Assistance Required for MacBook Air Activation: 1.75%
# - Urgent Support Needed: Dell XPS 13 Issue: 1.75%
# - Inquiry on MacBook Air M1 availability: 1.75%
# - Dell XPS 13 Overheating Issue: 1.75%
# - Urgent Support for Laptop Issue: 1.75%
# - Screen Flickering Issue with Dell XPS 13: 1.75%
# - Assistance needed for MacBook Air M1 keyboard: 1.75%
# - Immediate Assistance Required: Touchscreen Non-Responsive Problem: 1.75%
# - Battery Issue with Surface Pro: 1.75%
# - Inquiry on Samsung QLED TV Features: 1.75%
# - Exchange Request for Malfunctioning Dell XPS 13: 1.75%
# - Screen Flickering Issue on Dell XPS 13: 1.75%
# - Request for urgent assistance with Dell XPS 13 issues: 1.75%
# - Microsoft Surface Pro 7 Touchscreen Issue - Urgent Attention Required: 1.75%
# - Urgent: Dell XPS 13 9310 Laptop Not Powering On: 1.75%
# - MacBook Air M1 Power Issue: 1.75%
# - Urgent: Dell XPS 13 overheating and battery drain issue: 1.75%
# - Screen Flickering Issue on Surface Pro 7: 1.75%
# - Inquiry: MacBook Air M1 Graphic Design Software Compatibility: 1.75%
# - Inquiry about Dell XPS 13 9310 issues: 1.75%
# - Issue with Surface Pro 7 - Screen Flickering: 1.75%
# - Issue with Dell XPS 13 9310 Performance: 1.75%
# - Urgent Support Required: Battery Issues with MacBook Air M1: 1.75%
# - Concerns regarding MacBook Air M1 battery performance: 1.75%
# - Assistance Required for Amazon Navigation: 1.75%
# - Screen Flickering Issue: 1.75%
# - Inquiry Regarding Microsoft Surface Pro 7 Purchase: 1.75%
# - Login Issues with Microsoft Surface Pro 7: 1.75%
# - Surface Pro 7 Issue: 1.75%
# - Malfunctioning LG OLED C1 Display Issue: 1.75%
# - MacBook Air M1 Overheating Issues During Use: 1.75%
# - Performance Issue with Dell XPS 13 9310 Demo: 1.75%
# - Request for Exchange: Faulty MacBook Air M1 After Use: 1.75%
# - Touchscreen and Keyboard Issues with Surface Pro 7: 1.75%
# - Dell XPS 13 9310 Issues: 1.75%
# - Inquiry About Epson EcoTank ET-4760 Printer: 1.75%
# - Issue with Microsoft Surface Pro 7: 1.75%
# - Immediate Support Needed: Touchscreen Non-Responsive Problem: 1.75%
#
# Cluster 1 recurring issues:
# - Request for Server Administration Assistance: 0.71%
# - Urgent IT consulting required for server issues: 0.71%
# - Critical AWS Cost Enhancement: 0.71%
# - Assistance with AWS Management: 0.71%
# - Intermittent Connectivity Issues with AWS: 0.71%
# - Immediate Attention Required: 0.71%
# - Urgent: Resolve AWS Infrastructure Downtime Issue: 0.71%
# - High Priority Request: Server Administration Issues: 0.71%
# - Urgent AWS Support Needed: 0.71%
# - Critical Server Management Concern: 0.71%
# - Request for AWS Infrastructure Scaling Assistance: 0.71%
# - Issue with AWS Billing Charges: 0.71%
# - Urgent Request for AWS Infrastructure Optimization: 0.71%
# - Issue with Ticket System: 0.71%
# - Immediate Help Required for Billing Discrepancy: 0.71%
# - Urgent AWS Deployment Issues: 0.71%
# - Cloud Infrastructure Optimization: 0.71%
# - Request for Improvements: AWS Infrastructure Settings Update: 0.71%
# - Immediate Attention Required: AWS Outage Concern: 0.71%
# - Urgent: AWS Downtime Issue: 0.71%
# - Urgent Support Inquiry: 0.71%
# - Urgent Assistance Required for Server Downtime: 0.71%
# - Urgent Support Needed: 0.71%
# - Immediate Assistance Needed with Server Outage: 0.71%
# - High-Priority Concern: 0.71%
# - Urgent: Optimize AWS Infrastructure for Cost Efficiency: 0.71%
# - Urgent: Immediate IT Assistance Needed: 0.71%
# - Request for AWS Service Updates: 0.71%
# - Urgent Resolution Needed: 0.71%
# - Billing Assistance Required: 0.71%
# - Critical Situation: 0.71%
# - Urgent: Immediate Review Required on Email Server Configuration: 0.71%
# - Help Needed: Email Setup Problem: 0.71%
# - Billing Inquiry for Service Renewal: 0.71%
# - AWS Performance Issues: 0.71%
# - Immediate Assistance Needed to Resolve Server Outage: 0.71%
# - Urgent Issue with AWS Deployment: 0.71%
# - Request for Changes in AWS Management Dashboard: 0.71%
# - Request for IT Consulting Services: 0.71%
# - Urgent: Critical AWS Service Outage Experienced: 0.71%
# - AWS Service Update Request: 0.71%
# - Billing Issue with AWS Management Service: 0.71%
# - Urgent Help Needed: AWS Deployment Issue: 0.71%
# - Urgent Support Required for AWS Issue Resolution: 0.71%
# - Request for Billing Support: 0.71%
# - Billing Discrepancies: 0.71%
# - Critical AWS Connection Problem: 0.71%
# - Critical Problem: 0.71%
# - Inquiry About Economical AWS Management Alternatives: 0.71%
# - Critical Concern: 0.71%
# - AWS Authentication Issues: 0.71%
# - Immediate Assistance Needed: Issues with Server Management: 0.71%
# - Major Concern: 0.71%
# - Request for Expert Assistance: 0.71%
# - Billing Discrepancy with AWS Service: 0.71%
# - Critical Server Management Problem: 0.71%
# - Notification of Planned Maintenance: 0.71%
# - Urgent: Major AWS Outage: 0.71%
# - Urgent Assistance Required for AWS Issues: 0.71%
# - Urgent Support Required to Fix Server Downtime: 0.71%
# - Urgent Issue: Ticket System Integration: 0.71%
# - Immediate Assistance Required for Server Downtime: 0.71%
# - Request for Expert Consultation on Ticket System: 0.71%
# - Investigation into AWS Billing Discrepancy: 0.71%
# - Billing Discrepancy Issue: 0.71%
# - Modification Request: AWS Cost Optimization Strategy: 0.71%
# - Inquiry About IT Consulting: 0.71%
# - Billing Discrepancy: 0.71%
# - Critical AWS Cost Management: 0.71%
# - Immediate Attention Needed: 0.71%
# - Immediate Resolution Required for Server Downtime: 0.71%
# - Immediate Help Required for Invoicing Mistake: 0.71%
# - Immediate Assistance Needed: 0.71%
# - Request for billing details and payment options assistance: 0.71%
# - Urgent Server Admin Interface Issue: 0.71%
# - Database Design Change Request: 0.71%
# - High-Priority Problem: 0.71%
# - Billing Issues on AWS Services: 0.71%
# - Request for Guidance: Optimizing Server Configurations: 0.71%
# - Request for Change in AWS Configurations for Optimization: 0.71%
# - Urgent Request for Jira Ticket Modification: 0.71%
# - Urgent Resolution Required: 0.71%
# - Urgent: Service Outage During Scheduled Maintenance: 0.71%
# - Required Modifications for IT Ticket System Pipeline: 0.71%
# - Request for Change in AWS Management Configuration: 0.71%
# - Immediate Help Required for Server Outage Situation: 0.71%
# - Guidance on IT Consulting Services: 0.71%
# - Guidance Needed for IT Infrastructure Efficiency: 0.71%
# - Inquiry About JavaScript React Development Service: 0.71%
# - Urgent: Issues with AWS Management Service: 0.71%
# - Scheduled Maintenance Notice: 0.71%
# - Inquiry Regarding Updates on AWS Services: 0.71%
# - High Priority Incident: Immediate AWS Deployment Resolution Needed: 0.71%
# - Request for Configuration Changes: 0.71%
# - Issues with AWS Management Service Deployment: 0.71%
# - Urgent: MySQL Database Configuration Issue: 0.71%
# - IT Consulting Inquiry: 0.71%
# - Urgent AWS Connectivity Issue: 0.71%
# - Urgent: Immediate Resolution Required for AWS Downtime: 0.71%
# - Double Billing Issue on Purchase: 0.71%
# - Urgent: AWS Management Service Issues: 0.71%
# - Urgent Request for Assistance: 0.71%
# - Issues with AWS Resource Optimization: 0.71%
# - Urgent: AWS Web Access Issue Resolution Required: 0.71%
# - Ticket Raised: AWS Resources Misconfiguration Issue: 0.71%
# - Inquiry for Professional Support: 0.71%
# - Urgent Assistance Required for AWS Optimization: 0.71%
# - Assistance Required for AWS Deployment: 0.71%
# - AWS Cost Optimization Help: 0.71%
# - Urgent Assistance Needed on Billing Error: 0.71%
# - Request for Server Configuration Changes: 0.71%
# - Critical: Significant AWS Service Disruption: 0.71%
# - Assistance Required: Software and Server Issues: 0.71%
# - AWS Deployment Issues: 0.71%
# - Infrastructure Assistance Request: 0.71%
# - Urgent: Ticket System Errors: 0.71%
# - Urgent AWS Support Required: 0.71%
# - Urgent: AWS Management Service Down: 0.71%
# - Request for Cost-Effective AWS Management Solutions: 0.71%
# - Requesting Expert Guidance: 0.71%
# - Request for Server Consultation: 0.71%
# - Critical: AWS Outage Situation: 0.71%
# - Assistance Required: Email Configuration Issue: 0.71%
# - Service Charge Clarification: 0.71%
# - Immediate AWS Assistance: 0.71%
# - Inquiry About Features and Pricing Options for React: 0.71%
# - Request for Refund Due to Incorrect Billing: 0.71%
# - High Priority: Delay in Server Setup Disrupting Client Activities: 0.71%
# - Urgent Assistance Needed for Ticket System: 0.71%
# - High Priority Request for Assistance: 0.71%
# - Assistance with IT Consultancy Options: 0.71%
# - AWS Management Service Inquiry: 0.71%
# - Request for Detailed Information on React Services: 0.71%
# - Update Required: Billing Information for Google Workspace: 0.71%
# - Urgent Issue: 0.71%
# - Immediate Assistance Required: 0.71%
# - Urgent Assistance Needed for AWS Access Issue: 0.71%
# - Urgent AWS Optimization: 0.71%
# - Request for Optimization of AWS Cloud Resources and Stability: 0.71%
# - Immediate Assistance Requested: 0.71%
#
# Cluster 2 recurring issues:
# - Urgent Assistance Needed: 1.54%
# - Request for Jira Software Enhancements: 1.54%
# - Immediate Support Required for Connectivity Issues: 1.54%
# - Zoom Video Conferencing Issues: 1.54%
# - Urgent Excel Macro Issue: 1.54%
# - Immediate Assistance Required: Visual Studio Code Crashing: 1.54%
# - Request for UI Components Update: 1.54%
# - Critical: Problem with AWS Deployment: 1.54%
# - Urgent Assistance Needed for Jira Software License Issue: 1.54%
# - Real-time Messaging Issues: 1.54%
# - Access Issue with Jira Software: 1.54%
# - IntelliJ IDEA 2024.1 Crashes Post Update: 1.54%
# - Immediate Attention Required: Connectivity Problem with PostgreSQL Database: 1.54%
# - Assistance Needed: Jira Software 8.20 Configuration: 1.54%
# - Performance Issues with MySQL 8.0.30 Database: 1.54%
# - New Jira Project Setup: 1.54%
# - Gmail Syncing Issue: 1.54%
# - Zoom 5.11.0 Connection Issues: 1.54%
# - Upgrade Zoom Request: 1.54%
# - Assistance with Adobe Photoshop: 1.54%
# - Request for Assistance with Office 365 Installation Error: 1.54%
# - Urgent: Google Workspace Services Down: 1.54%
# - Issues with IntelliJ IDEA 2024.1 Refactoring Features: 1.54%
# - Urgent: Zoom Application Down: 1.54%
# - High Priority: Zoom Service Outage: 1.54%
# - Frequent Database Downtime Issues: 1.54%
# - Urgent Assistance Needed: Issue with AWS Deployment: 1.54%
# - Request to upgrade IntelliJ IDEA for improved features: 1.54%
# - Immediate Resolution Needed: Zoom 5.11.0 Crashes: 1.54%
# - Alert: User Interface Issue in React Application: 1.54%
# - Urgent: Jira Ticket System Disruption: 1.54%
# - Error with Slack Channel Integration: 1.54%
# - Urgent: AWS deployment issue: 1.54%
# - Bug Report: UI Bug in React App: 1.54%
# - Recurrent Excel Crash Issue Post Update: 1.54%
# - Issues Setting Up AWS EC2 Security Group: 1.54%
# - Urgent Care Needed: Issue with AWS Deployment: 1.54%
# - Urgent: User unable to join scheduled Zoom meeting: 1.54%
# - Urgent Assistance Needed for Zoom Issues: 1.54%
# - Urgent Resolution Needed: VS Code Crashing: 1.54%
# - Missing ticket notifications impacting Jira feedback: 1.54%
# - Urgent Update Required for Jira Software 8.20: 1.54%
# - Oracle Database 19c Connectivity Issue: 1.54%
# - Immediate Fix Needed for Jira Crashes: 1.54%
# - Assistance Required: Issue with Adobe Photoshop 2024 Installation: 1.54%
# - Frequent audio issues with Zoom application: 1.54%
# - Urgent: Frequent PostgreSQL Server Crashes: 1.54%
# - Urgent: Assistance Needed for MySQL 8.0.30 Data Loss Recovery: 1.54%
# - Jira Software Efficiency Issue: 1.54%
# - Excel Intermittent Crashing Issue: 1.54%
# - Immediate Support Required: 1.54%
# - Google Workspace: 1.54%
# - Assistance Needed: Reset Password for Office 365: 1.54%
# - Slack 4.23.0 Issues: 1.54%
# - Urgent License Error: 1.54%
# - Request for Change in User Permissions Setup: 1.54%
# - Urgent Help Needed: Adobe Photoshop 2024 Access Issue: 1.54%
# - Urgent Issue: Email Access in Office 365: 1.54%
# - Urgent: Issue Connecting to PostgreSQL Database: 1.54%
# - Jira Workflow Update: 1.54%
# - Billing Issues with Adobe Photoshop: 1.54%
# - Software Update Request: 1.54%
# - Excel Version Update Request: 1.54%
# - Inquiry on Jira 8.20 Assistance: 1.54%
# - Urgent Assistance Required: Issue with AWS Deployment: 1.54%
#
# Cluster 3 recurring issues:
# - Urgent: Critical impact on enterprise network connectivity: 1.30%
# - Issues with Cisco ISR4331 Router: 1.30%
# - Problems with Network Stability: 1.30%
# - Network Connectivity Issues: 1.30%
# - Assistance Required for HP DeskJet 3755 Paper Jams: 1.30%
# - Network Instability Issue: 1.30%
# - Urgent: Network Outage: 1.30%
# - Urgent: Cisco ISR4331 Issues: 1.30%
# - Assistance Required: Wireless Connectivity Issue with HP DeskJet 3755: 1.30%
# - Intermittent Connectivity Issues Report: 1.30%
# - Network Issues with Cisco Router: 1.30%
# - Help Needed: Printer Connection Problem: 1.30%
# - High Priority Incident: Router Connectivity Issues: 1.30%
# - Assistance with Printer Setup: 1.30%
# - Printer Settings Update Request: 1.30%
# - Malfunctioning Cisco Router ISR4331 Issue: 1.30%
# - Assistance Needed with Wireless Setup for Canon PIXMA MG3620: 1.30%
# - Assistance Required for Epson EcoTank ET-4760 Printer: 1.30%
# - Critical: Recurring Network Disconnection Problem: 1.30%
# - Issues with Cisco Router ISR4331: 1.30%
# - Assistance Needed for Epson EcoTank ET-4760 Paper Jams: 1.30%
# - Help Needed for Printer Connection Issue: 1.30%
# - High Priority: Recurring Network Disruptions: 1.30%
# - High Priority: Recurrent Network Disconnections Problem: 1.30%
# - Need Support: 1.30%
# - Help with Printer Configuration: 1.30%
# - Immediate Support Required: Cisco ISR4331 Router Outage: 1.30%
# - Seeking Assistance: Router Leading to Network Disruptions: 1.30%
# - Immediate Help Required: 1.30%
# - Problems with Network Reliability: 1.30%
# - Urgent Assistance Needed: Cisco ISR4331 Downtime: 1.30%
# - Canon PIXMA MG3620 Exchange Request: 1.30%
# - Assistance Required for Printer Setup: 1.30%
# - Requesting Support: Router causing network issues: 1.30%
# - Critical Issue: Network Interruption: 1.30%
# - Company Network Issue: 1.30%
# - Issue with Canon PIXMA MG3620 Wi-Fi Connection: 1.30%
# - Urgent: Critical Network Issue with Router ISR4331: 1.30%
# - Request to Return HP DeskJet 3755: 1.30%
# - Assistance Needed for Canon Setup: 1.30%
# - Intermittent Network Connectivity Issues: 1.30%
# - Urgent: Netgear Switch GS108 Connectivity Issue: 1.30%
# - Urgent Wireless Printing Issue Resolution: 1.30%
# - Connectivity Issues with Cisco Router: 1.30%
# - Support Request for Cisco Router ISR4331: 1.30%
# - Assistance Needed: 1.30%
# - Urgent: Epson EcoTank ET-4760 Paper Jam Issue: 1.30%
# - Urgent Router Issue: 1.30%
# - Request for Setup Assistance with HP DeskJet 3755: 1.30%
# - Critical: Recurring Network Disruption Problem: 1.30%
# - Intermittent connectivity on ISR4331: 1.30%
# - Intermittent Connectivity Issues with Cisco Router: 1.30%
# - Assistance Needed for Canon PIXMA MG3620 Print Quality Issue: 1.30%
# - Connectivity Issues: 1.30%
# - Wi-Fi Connectivity Issues with Canon PIXMA MG3620 Printer: 1.30%
# - Urgent: Cisco Router ISR4331 Network Connectivity Issues: 1.30%
# - Assistance Required: Printer Connectivity Issue: 1.30%
# - Assistance Needed for Printer Setup: 1.30%
# - Request for Assistance with Wireless Printing: 1.30%
# - Exchange Request for Canon PIXMA MG3620 Due to Print Quality Issues: 1.30%
# - Issue with HP DeskJet 3755 Connection: 1.30%
# - Frequent Printer Issues: 1.30%
# - Urgent Cisco Router Issue: 1.30%
# - Internet Connectivity Issues: 1.30%
# - Network Configuration Issue: 1.30%
# - Request for Product Exchange Due to Connectivity Issues: 1.30%
# - Network Connectivity Challenges Occurring Intermittently: 1.30%
# - Network Outage Due to Cisco Router ISR4331 Failure: 1.30%
# - Questions About Printer Replacement: 1.30%
# - Urgent: Connectivity Issues with Cisco Router ISR4331: 1.30%
# - Urgent: Frequent Network Drops Issue: 1.30%
# - Cisco Router Outage: 1.30%
# - Printer Setup Assistance: 1.30%
# - Request for exchange due to connectivity issues: 1.30%
# - Intermittent Network Issues: 1.30%
# - Frequent Disconnect Issues with Cisco Router ISR4331: 1.30%
# - Request for Support: 1.30%
# <ipython-input-22-1979d90fe5f6>:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# prompt: give a name to this clusters by identifying the product name like cisco router,aws,dell xps,printer this way by nalysing what product its talking about

import pandas as pd

def name_clusters(cluster_data):
    """
    Names clusters based on the most frequent product names found in subjects.
    """
    cluster_names = {}
    for cluster_id in cluster_data:
        subjects = cluster_data[cluster_id]
        product_counts = {}
        for subject in subjects:
          # Lowercase the subject for case-insensitive matching
          subject = subject.lower()

          if "cisco" in subject and "router" in subject:
              product_counts["Cisco Router"] = product_counts.get("Cisco Router", 0) + 1
          elif "aws" in subject:
              product_counts["AWS"] = product_counts.get("AWS", 0) + 1
          elif "dell xps" in subject:
              product_counts["Dell XPS"] = product_counts.get("Dell XPS", 0) + 1
          elif "printer" in subject:
              product_counts["Printer"] = product_counts.get("Printer", 0) + 1
          # Add more product checks here

        # Find the most frequent product
        if product_counts:
            most_frequent_product = max(product_counts, key=product_counts.get)
            cluster_names[cluster_id] = most_frequent_product
        else:
            cluster_names[cluster_id] = f"Cluster {cluster_id} (Unknown)"
    return cluster_names

# Example usage (replace with your actual cluster data)
cluster_data = {
    0: ["Dell XPS screen problem"],
    1: ["AWS Connection Problem", "AWS Server Error", "AWS Management Console Issue"],
    2: ["Cisco Router Configuration", "Cisco Router Reboot", "Cisco Router Connectivity"],
    3: ["Printer Jam", "Printer Out of Ink", "HP Printer Offline"]
}


cluster_names = name_clusters(cluster_data)
print(cluster_names)


# Integrate with your existing code

# ... (your existing code) ...

# After k-means clustering
# Assuming df_eng['cluster'] now contains the cluster labels for English tickets

# Group subjects by cluster
clustered_subjects = df_eng.groupby('cluster')['subject'].apply(list).to_dict()

# Name clusters using the function
cluster_names = name_clusters(clustered_subjects)

# Print or use the cluster names
for cluster_id, name in cluster_names.items():
    print(f"Cluster {cluster_id}: {name}")
# Out:
# {0: 'Dell XPS', 1: 'AWS', 2: 'Cisco Router', 3: 'Printer'}
# Cluster 0: Dell XPS
# Cluster 1: AWS
# Cluster 2: AWS
# Cluster 3: Cisco Router

# %%
# prompt: give persentage coverage of each cluster in data set, give percenatge of issue in a way for example cisco router: 30% in this way for other 2/3 category of cluster name

# Assuming df_eng and the 'cluster' column are already defined from the previous code.

cluster_percentages = {}

for cluster_id in df_eng['cluster'].unique():
    cluster_subset = df_eng[df_eng['cluster'] == cluster_id]
    total_tickets_in_cluster = len(cluster_subset)

    # Initialize a dictionary to store issue counts for this cluster
    issue_counts = {}

    for subject in cluster_subset['subject']:
      # Lowercase the subject for case-insensitive matching
      subject = subject.lower()

      if "cisco" in subject and "router" in subject:
          issue = "Cisco Router"
      elif "aws" in subject:
          issue = "AWS"
      elif "dell xps" in subject:
          issue = "Dell XPS"
      elif "printer" in subject:
          issue = "Printer"
      else:
          issue = "Other"  # Catch-all for other issues

      issue_counts[issue] = issue_counts.get(issue, 0) + 1

    cluster_percentages[cluster_id] = {}
    for issue, count in issue_counts.items():
        percentage = (count / total_tickets_in_cluster) * 100
        cluster_percentages[cluster_id][issue] = percentage

# Print the results
for cluster_id, issue_data in cluster_percentages.items():
  print(f"Cluster {cluster_id}:")
  for issue, percentage in issue_data.items():
    print(f"  {issue}: {percentage:.2f}%")
# Out:
# Cluster 3:
#   Other: 64.94%
#   Printer: 16.88%
#   Cisco Router: 18.18%
# Cluster 0:
#   Dell XPS: 29.82%
#   Other: 66.67%
#   Printer: 3.51%
# Cluster 1:
#   Other: 58.57%
#   AWS: 41.43%
# Cluster 2:
#   Other: 90.77%
#   AWS: 9.23%

# %%
# prompt: from this clusters make Generates a response template."""
# #         template = (
# #             f"Subject: Re: {issue_params.get('specific_issue', '<specific_issue>')}\n\n"
# #             f"Dear {issue_params.get('customer_name', '<name>')},\n\n"
# #             f"Thank you for contacting us regarding {issue_params.get('specific_issue', '<specific_issue>')}.\n"
# #             f"{issue_params.get('resolution_steps', '<resolution_steps>')}\n\n"
# #             f"Best regards,\n{issue_params.get('team_name', 'Support Team')}"
# #         ) in this way for response automation for these clusters, create 4 templates for this for clusters

def generate_response_template(cluster_id, issue_params):
    """Generates a response template based on the cluster ID and issue parameters."""

    if cluster_id == 0:  # Example: Cluster 0 - Dell XPS issues
        template = (
            f"Subject: Re: {issue_params.get('specific_issue', 'Dell XPS Issue')}\n\n"
            f"Dear {issue_params.get('customer_name', '<name>')},\n\n"
            f"Thank you for contacting us regarding your Dell XPS issue.\n"
            f"Please try these steps:\n"
            f"1. {issue_params.get('resolution_step_1', 'Restart your computer')}\n"
            f"2. {issue_params.get('resolution_step_2', 'Check the power adapter')}\n\n"
            f"If the issue persists, please provide more details.\n\n"
            f"Best regards,\nDell XPS Support Team"
        )
    elif cluster_id == 1:  # Example: Cluster 1 - AWS issues
        template = (
            f"Subject: Re: {issue_params.get('specific_issue', 'AWS Issue')}\n\n"
            f"Dear {issue_params.get('customer_name', '<name>')},\n\n"
            f"Thank you for contacting us regarding your AWS issue. \n"
            f"{issue_params.get('resolution_steps', 'Please check the AWS documentation for troubleshooting steps.')}\n\n"
            f"Best regards,\nAWS Support Team"
        )
    elif cluster_id == 2:  # Example: Cluster 2 - Cisco Router issues
        template = (
            f"Subject: Re: {issue_params.get('specific_issue', 'Cisco Router Issue')}\n\n"
            f"Dear {issue_params.get('customer_name', '<name>')},\n\n"
            f"Thank you for contacting us about your Cisco Router issue. \n"
            f"{issue_params.get('resolution_steps', 'Verify your router’s configuration and check connections.')}\n\n"
            f"1. {issue_params.get('resolution_step_1', 'Restart your computer')}\n"
            f"2. {issue_params.get('resolution_step_2', 'Check the power adapter')}\n\n"
            f"If these don't improve the situation, please reach out with the router logs and any error messages you may have observed, and we'll investigate further.\n"


            f"Feel free to contact us at your convenience for further assistance. We aim to resolve this promptly so you can resume your normal work activities.\n"
            f"Best regards,\nCisco Router Support"
        )
    elif cluster_id == 3:  # Example: Cluster 3 - Printer issues
        template = (
            f"Subject: Re: {issue_params.get('specific_issue', 'Printer Issue')}\n\n"
            f"Dear {issue_params.get('customer_name', '<name>')},\n\n"
            f"Thank you for contacting us regarding your printer issue.\n"
            f"{issue_params.get('resolution_steps', 'Check the printer’s power cord and ink levels.')}\n\n"
            f"Best regards,\nPrinter Support"
        )
    else:
        template = (
            f"Subject: Re: {issue_params.get('specific_issue', '<specific_issue>')}\n\n"
            f"Dear {issue_params.get('customer_name', '<name>')},\n\n"
            f"Thank you for contacting us regarding {issue_params.get('specific_issue', '<specific_issue>')}.\n"
            f"{issue_params.get('resolution_steps', '<resolution_steps>')}\n\n"
            f"Best regards,\n{issue_params.get('team_name', 'Support Team')}"
        )

    return template

# %%
# prompt: give a function that takes input as incoming issues in format as {"subject":" ","body":" "} and gives its automatted response by extracting the issue from the subject and body then matching with the template as provided by above function, dont write another function to generate template use the above function of generate_response_template only and just give the parameters to it. also import necessary libraries, provide appropriate parameters to generate_response_template as well
import pickle,os
def automated_response(incoming_issue):
    # Assuming clusters are predefined for issue matching
    clusters = {
        0: "dell xps",
        1: "aws",
        2: "cisco router",
        3: "printer",
    }

    # Preprocess the incoming issue
    incoming_subject = incoming_issue["subject"].lower()
    incoming_body = incoming_issue["body"].lower()

    best_cluster = None
    best_similarity = -1  # Initialize with a low similarity score

    for cluster_id, cluster_keyword in clusters.items():
        if cluster_keyword in incoming_subject or cluster_keyword in incoming_body:
            best_similarity = 1  # High similarity for keyword match
            best_cluster = cluster_id
            break

    if best_cluster is not None:
        issue_params = {
            "specific_issue": incoming_issue.get("subject", "Technical Issue"),
            "customer_name": "Customer",  # Example placeholder
            "resolution_step_1": "Restart your device",
            "resolution_step_2": "Check your connections",
            "resolution_steps": "Follow the recommended troubleshooting steps for your device.",
            "team_name": "Support Team",
        }

        return generate_response_template(best_cluster, issue_params)

    # Default response if no match found
    return "I'm sorry, I couldn't find an appropriate response for your issue. Please provide more details."


# Example incoming issue
incoming_issue = {
    "subject": "Critical impact on enterprise network connectivity",
    "body": """Dear Customer Support Team,
    We are experiencing a complete outage affecting our enterprise network involving Cisco Router ISR4331.
    This disruption is critically impacting our secure WAN connectivity across all domains, urgently requiring your immediate intervention.
    Due to this issue, our company has halted various essential operations, significantly affecting our services and commitments to clients.
    As our technical team has not been able to resolve the problem internally, we need your expert support to diagnose and rectify this issue swiftly.
    Please consider this a high priority and provide us with the necessary technical assistance to restore our network’s functionality.
    Thank you for your prompt attention.
    Best regards,
    <Kane>, IT Manager at <company>."""
}

response = automated_response(incoming_issue)
print(response)

response_result = response


# Create the directory if it doesn't exist
os.makedirs('model', exist_ok=True)
with open('model/response_automation_output.pkl', 'wb') as f:
    pickle.dump(response_result, f)
# Out:
# Subject: Re: Critical impact on enterprise network connectivity
#
# Dear Customer,
#
# Thank you for contacting us about your Cisco Router issue.
# Follow the recommended troubleshooting steps for your device.
#
# 1. Restart your device
# 2. Check your connections
#
# If these don't improve the situation, please reach out with the router logs and any error messages you may have observed, and we'll investigate further.
# Feel free to contact us at your convenience for further assistance. We aim to resolve this promptly so you can resume your normal work activities.
# Best regards,
# Cisco Router Support
